# %% [markdown]
# # Define `Rest-of-World`s in ecoinvent 3.01-3.2
#
# This notebook shows how the various `Rest-of-World`s were spatially defined for ecoinvent versions 3.01, 3.1, and 3.2 (all system models).
#
# ## Start new project

# %%
from brightway2 import *
from bw2regional.ecoinvent import *
import pyprind
# Out:
# Warning: bad escape \s

# %%
projects.current = "Ecoinvent 3"

# %%
bw2setup()
# Out:
# Biosphere database already present!!! No setup is needed

# %% [markdown]
# ## Import ecoinvents

# %%
ecoinvents = [
    ("ecoinvent 3.01 cutoff", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.01/cutoff/datasets"),
    ("ecoinvent 3.01 apos", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.01/default/datasets"),
    ("ecoinvent 3.01 consequential", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.01/consequential/datasets"),
    ("ecoinvent 3.1 consequential", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.1/consequential/datasets"),
    ("ecoinvent 3.1 cutoff", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.1/cutoff/datasets"),
    ("ecoinvent 3.1 apos", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.1/default/datasets"),
    ("ecoinvent 3.2 consequential", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.2/consequential/datasets"),
    ("ecoinvent 3.2 cutoff", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.2/cutoff/datasets"),
    ("ecoinvent 3.2 apos", "/Users/cmutel/Documents/LCA Documents/Ecoinvent/3.2/apos/datasets")
]

# %%
def import_all_ecoinvents():
    for name, fp in ecoinvents:
        print(name)
        ei = SingleOutputEcospold2Importer(fp, name)
        ei.apply_strategies()
        if ei.statistics()[2]:
            ei.drop_unlinked(True)
        ei.write_database()
        ei = None

# %%
if 'ecoinvent 3.01 cutoff' not in databases:
    import_all_ecoinvents()

# %% [markdown]
# # Fix `ecoinvent` shortnames
#
# There are a few changes which haven't propogated to ecoinvent master yet.

# %%
for name, fp in ecoinvents:
    print(name)
    db = Database(name)
    db.make_unsearchable()

    bar = pyprind.ProgBar(len(db))
    
    for act in db:
        old_location = act['location']
        new_location = convert_default_ecoinvent_locations(old_location)
        if old_location != new_location:
            act['location'] = new_location
            act.save()
        bar.update()
            
    print()
# Out:
# 0%                          100%
# [                              ]
# ecoinvent 3.01 cutoff
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:10
# ecoinvent 3.01 apos
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:00:48
# ecoinvent 3.01 consequential
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:16
# ecoinvent 3.1 consequential
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:13
# ecoinvent 3.1 cutoff
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:03
# ecoinvent 3.1 apos
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:31
# ecoinvent 3.2 consequential
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:45
# ecoinvent 3.2 cutoff
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:02:02
# ecoinvent 3.2 apos
# 0%                          100%
# [##############################] | ETA: 00:00:00
# Total time elapsed: 00:01:15

# %% [markdown]
# # Call `discretize_rest_of_world` on ecoinvent 3.2 cutoff
#
# This function will return the following:
#
# * `activity_dict`: Dictionary from activity keys to `(activity name, reference product)`
# * `row_locations`: List of `(tuple excluded locations, new RoW label)`, where new RoW labels are like `"RoW-42"`.
# * `locations`: Dictionary from keys of `(activity name, reference product)` to all the specific locations defined for this activity/product combination.
# * `exceptions`: List of `(activity name, reference product)` markets for which no `RoW` activity is present.

# %%
activity_dict, row_locations, locations, exceptions = discretize_rest_of_world("ecoinvent 3.2 cutoff", warn=False)

# %%
len(activity_dict), len(row_locations), len(locations), len(exceptions)
# Out:
# Warning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
# Warning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
# (2792, 140, 2792, 516)

# %%
activity_dict
# Out:
# {('ecoinvent 3.2 cutoff',
#   '2603f9863e3b9205d9044cdb123e9d54'): ('operation, computer, laptop, 68% active work', 'operation, computer, laptop, 68% active work'),
#  ('ecoinvent 3.2 cutoff',
#   'ae35b7b996a39a461cbf95e06ae18235'): ('operation, solar collector system, evacuated tube collector, one-family house, for combined system', 'heat, central or small-scale, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '62383ff55b252b0f18603bb6839e7f08'): ('citric acid production', 'phosphate fertiliser, as P2O5'),
#  ('ecoinvent 3.2 cutoff',
#   '3494b01d14597bb6cf91cacb1384a2f0'): ('concrete production 35MPa, RNA only', 'concrete, 35MPa'),
#  ('ecoinvent 3.2 cutoff',
#   '7399e0233bef3a6ee8bec276ddde5ff8'): ('ground granulated blast furnace slag production', 'blast furnace slag'),
#  ('ecoinvent 3.2 cutoff',
#   '506be6ba7a756b5f72d1f56f694a27e9'): ('photovoltaic slanted-roof installation, 3kWp, CdTe, laminated, integrated, on roof', 'photovoltaic slanted-roof installation, 3kWp, CdTe, laminated, integrated, on roof'),
#  ('ecoinvent 3.2 cutoff',
#   'a08a0ec3266df63c729f22d4bdf1f15e'): ('treatment of refinery sludge, hazardous waste incineration', 'refinery sludge'),
#  ('ecoinvent 3.2 cutoff',
#   'a98f8cb530611b695691ea857d53f581'): ('rape seed production, organic', 'rape seed, organic'),
#  ('ecoinvent 3.2 cutoff',
#   '2316cb2af2928622ae5c97fe32079912'): ('photovoltaic panel production, multi-Si wafer', 'photovoltaic panel, multi-Si wafer'),
#  ('ecoinvent 3.2 cutoff',
#   '2cb40941711eea9c14c342ee7c0755bc'): ('bromine production', 'bromine'),
#  ('ecoinvent 3.2 cutoff',
#   'b54050479387ed48d7f7ea292a095f2e'): ('paper production, newsprint, recycled',
#   'paper, newsprint'),
#  ('ecoinvent 3.2 cutoff',
#   'ef44cba4ac038474d2db4daf991312d5'): ('laser machining, metal, with YAG-laser, 120W power', 'laser machining, metal, with YAG-laser, 120W power'),
#  ('ecoinvent 3.2 cutoff',
#   '936a03d0001eae94c2c4fdc4a3069f6d'): ('sodium hydrogen sulfite production', 'sodium hydrogen sulfite'),
#  ('ecoinvent 3.2 cutoff',
#   '8a562f161757ba4aa28dd82afb38dbf9'): ('treatment of aluminium scrap, post-consumer, by collecting, sorting, cleaning, pressing', 'aluminium scrap, post-consumer, prepared for melting'),
#  ('ecoinvent 3.2 cutoff',
#   '6f218c81b9a8397b790426f18237bd00'): ('planing, board, softwood, u=20%', 'sawnwood, board, softwood, dried (u=20%), planed'),
#  ('ecoinvent 3.2 cutoff',
#   '251179b261ea2618054f8bfdbdc70899'): ('acetoacetic acid production', 'acetoacetic acid'),
#  ('ecoinvent 3.2 cutoff',
#   '3871ed325d7abe97986cbb5b333ba1a1'): ('air separation, cryogenic', 'nitrogen, liquid'),
#  ('ecoinvent 3.2 cutoff',
#   '2c550adc52e6ddbc772f64637276a247'): ('furnace production, wood chips, average storage area, 50kW', 'furnace, wood chips, average storage area, 50kW'),
#  ('ecoinvent 3.2 cutoff',
#   '27c3261bc630516aa8bb74a994294c96'): ('transport, passenger car, large size, petrol, EURO 3', 'transport, passenger car, large size, petrol, EURO 3'),
#  ('ecoinvent 3.2 cutoff',
#   '0fa7a3cb94ca7d4a3c794868a19837e9'): ('ethylene carbonate production', 'ethylene carbonate'),
#  ('ecoinvent 3.2 cutoff',
#   'e9a89b698166ff24c88afdb7c04ac457'): ('treatment of manure and biowaste by anaerobic digestion, from used vegetable cooking oil', 'biogas'),
#  ('ecoinvent 3.2 cutoff',
#   '46b2c2f04a3e73219bc24521d953df0f'): ('soybean meal and crude oil production, mechanical extraction', 'protein feed, 100% crude'),
#  ('ecoinvent 3.2 cutoff',
#   '1e41652580b2228b58ac899fb23bdf9a'): ('pentaerythritol production in sodium hydroxide solution', 'sodium formate'),
#  ('ecoinvent 3.2 cutoff',
#   '80a0a8e8cf87bdf201ebeee2c07cef9c'): ('lime production, hydrated, packed', 'lime, hydrated, packed'),
#  ('ecoinvent 3.2 cutoff',
#   'cf542954d591aba2860b17161ccbfa74'): ('treatment of scrap aluminium, municipal incineration', 'scrap aluminium'),
#  ('ecoinvent 3.2 cutoff',
#   '2bc74c3f5d329ee141176e9c201ef16b'): ('cooling energy, from natural gas, at cogen unit with absorption chiller 100kW', 'cooling energy'),
#  ('ecoinvent 3.2 cutoff',
#   '9980ce0f2ef60dbae24810732a1a5bff'): ('drying of grass', 'drying of grass'),
#  ('ecoinvent 3.2 cutoff',
#   '46634c37e75f62eaf24576869330f065'): ('hazardous waste incineration facility construction',
#   'hazardous waste incineration facility'),
#  ('ecoinvent 3.2 cutoff',
#   '5e5e4c851afc859531934c80255f33f3'): ('dipropylene glycol monomethyl ether production', 'dipropylene glycol monomethyl ether'),
#  ('ecoinvent 3.2 cutoff',
#   '96b1731edd6e37ba0cc5a28c743943f9'): ('hardwood forestry, azobe, sustainable forest management', 'roundwood, azobe from sustainable forest management, under bark'),
#  ('ecoinvent 3.2 cutoff',
#   '5d66bdbeffa1359f00690ef05fed306e'): ('methane production, 96% by volume, from biogas, from high pressure network, at service station', 'methane, 96% by volume, from biogas, from high pressure network, at service station'),
#  ('ecoinvent 3.2 cutoff',
#   'edd76b5725f10e657ff69086d644d209'): ('chlor-alkali electrolysis, diaphragm cell', 'chlorine, gaseous'),
#  ('ecoinvent 3.2 cutoff',
#   'bb21bb547366dfe458cf6cacac277d83'): ('maize silage production, organic', 'maize silage, organic'),
#  ('ecoinvent 3.2 cutoff',
#   '24003daefb9bb85ff8e176cf27fd4daa'): ('thermoforming production, with calendering', 'thermoforming, with calendering'),
#  ('ecoinvent 3.2 cutoff',
#   '41833272dafcb53ab4c884eabc4e25af'): ('gold-silver mine operation with refinery', 'silver'),
#  ('ecoinvent 3.2 cutoff',
#   '7d5e5a0cc4f380904aea9a9e4500f873'): ('chromium steel drilling, conventional', 'chromium steel removed by drilling, conventional'),
#  ('ecoinvent 3.2 cutoff',
#   '5d144d91d45af999e69384e78d9a0814'): ('heat and power co-generation unit construction, 160kW electrical, components for electricity only', 'heat and power co-generation unit, 160kW electrical, components for electricity only'),
#  ('ecoinvent 3.2 cutoff',
#   '0c8e506142b418e7089dfae54136c412'): ('operation, dried roughage store, air dried, solar', 'operation, dried roughage store, air dried, solar'),
#  ('ecoinvent 3.2 cutoff',
#   'c42da79ccf8b22f0a09395446c5d3904'): ('thionyl chloride production', 'thionyl chloride'),
#  ('ecoinvent 3.2 cutoff',
#   'ea0e737e095ba671bc2b4db2dadab89a'): ('market for paper, woodfree, uncoated', 'paper, woodfree, uncoated'),
#  ('ecoinvent 3.2 cutoff',
#   'e621c369481af7466d50f7b3d8e05edd'): ('recultivation, bentonite mine', 'recultivation, bentonite mine'),
#  ('ecoinvent 3.2 cutoff',
#   '8389af294329c4749cc2e2c82cf835c6'): ('drying of maize straw and whole-plant', 'drying of maize straw and whole-plant'),
#  ('ecoinvent 3.2 cutoff',
#   'c05ef725a9cfc71c55808f5221d0e9a8'): ('heat and power co-generation, diesel, 200kW electrical, SCR-NOx reduction', 'electricity, high voltage'),
#  ('ecoinvent 3.2 cutoff',
#   'b2af11ca90857795123214a365e733b9'): ('uranium production, centrifuge, enriched 4.2%', 'uranium, enriched 4.2%, per separative work unit'),
#  ('ecoinvent 3.2 cutoff',
#   '00d7ea7df0997de56704edb66e311e8f'): ('nuclear spent fuel reprocessing facility construction', 'nuclear spent fuel reprocessing facility'),
#  ('ecoinvent 3.2 cutoff',
#   '718b0ad1d9e9846fdca1270e61326775'): ('housing system construction, cattle, loose', 'housing system, cattle, loose, per animal unit'),
#  ('ecoinvent 3.2 cutoff',
#   '3541b22628a429bc8a9eaee50f245679'): ('heat production, natural gas, at boiler atm. low-NOx condensing non-modulating <100kW', 'heat, central or small-scale, natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '2b008e933756225e09fc9b34bdd2e904'): ('treatment of waste polystyrene, municipal incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   'd59066d910406fb6fa725f57ba29178c'): ('treatment of municipal solid waste, sanitary landfill', 'municipal solid waste'),
#  ('ecoinvent 3.2 cutoff',
#   'e7eabbbd0f696ae5b115e2ee32842e57'): ('treatment of waste polystyrene isolation, flame-retardant, collection for final disposal', 'waste polystyrene isolation, flame-retardant'),
#  ('ecoinvent 3.2 cutoff',
#   '92de0fd68dd0d6ed086133e9039d2e43'): ('treatment of waste plastic, mixture, municipal incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '4cc55d53eb08488af38a2e477c7ff598'): ('tillage, cultivating, chiselling', 'tillage, cultivating, chiselling'),
#  ('ecoinvent 3.2 cutoff',
#   '4e109799558031c6a486ba1d88ac454c'): ('transport, passenger car, EURO 3', 'transport, passenger car, EURO 3'),
#  ('ecoinvent 3.2 cutoff',
#   '392b9b17fb64923c1e0317288262cf1b'): ('trichloroacetic acid production', 'trichloroacetic acid'),
#  ('ecoinvent 3.2 cutoff',
#   '996a63016f52fdae5a7115a2ccdf2ea1'): ('wooden board factory construction, cement bonded boards', 'wooden board factory, cement bonded boards'),
#  ('ecoinvent 3.2 cutoff',
#   '5f27b570ce516e34b184402080293151'): ('heat production, softwood chips from forest, at furnace 300kW', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   'e899d4f4f696c64ebe078eacf76151c3'): ('treatment of waste paint on wood, collection for final disposal', 'waste paint on wood'),
#  ('ecoinvent 3.2 cutoff',
#   'beeeeffc2964f139653a158366bcd873'): ('EDTA production', 'EDTA, ethylenediaminetetraacetic acid'),
#  ('ecoinvent 3.2 cutoff',
#   'a075eb778f24299854c70ed7171c516a'): ('fluorescent whitening agent production, DAS1, triazinylaminostilben type', 'fluorescent whitening agent, DAS1, triazinylaminostilben type'),
#  ('ecoinvent 3.2 cutoff',
#   '8e47a1d5e5c38016ed4a340ec0ce589b'): ('maintenance, goods wagon', 'maintenance, goods wagon'),
#  ('ecoinvent 3.2 cutoff',
#   'bec478c236e2dc52ccbec051556f8087'): ('nuclear waste storage construction, interim, for low level radioactive waste before final repository', 'nuclear waste storage, interim, for low level radioactive waste before final repository'),
#  ('ecoinvent 3.2 cutoff',
#   'fc0b50dffde1861c4b878960d8e3cc3f'): ('treatment, sludge from pulp and paper production, landfarming', 'nitrogen fertiliser, as N'),
#  ('ecoinvent 3.2 cutoff',
#   '7b580e16dcada061d300be5045bcdae3'): ('triethyl amine production', 'triethyl amine'),
#  ('ecoinvent 3.2 cutoff',
#   '988a7e80cd947d3cc3e2606c4cf0d358'): ('citric acid production', 'citric acid'),
#  ('ecoinvent 3.2 cutoff',
#   'c1e1ebdf3f928c49c0d268f764c8c940'): ('natural gas service station construction', 'natural gas service station'),
#  ('ecoinvent 3.2 cutoff',
#   'ecadb375008f580cf99e06326fc3abd5'): ('wood preservation, vacuum pressure method, inorganic salt, containing Cr, outdoor use, ground contact', 'wood preservation, vaccum pressure method, inorganic salt, containing Cr, outdoor use, ground contact'),
#  ('ecoinvent 3.2 cutoff',
#   '1ae4409af642248aef272dcb2433ab6f'): ('potato production', 'potato'),
#  ('ecoinvent 3.2 cutoff',
#   'da443a99db4872a19eb9d930017decc0'): ('sawnwood production, softwood, raw, dried (u=20%)',
#   'sawnwood, softwood, raw, dried (u=20%)'),
#  ('ecoinvent 3.2 cutoff',
#   '8846a0c0422b9f5302abf500f30fadaf'): ('agricultural machinery production, unspecified', 'agricultural machinery, unspecified'),
#  ('ecoinvent 3.2 cutoff',
#   'e1bc8bf0ed60ada42d1aa0e4d804a1ee'): ('straw production, stand-alone production', 'straw, stand-alone production'),
#  ('ecoinvent 3.2 cutoff',
#   'ee2ac3a9a58a7ff99edf4a543082232a'): ('ventilation duct production, elbow 90°, steel, 100x50 mm', 'ventilation duct, elbow 90°, steel, 100x50 mm'),
#  ('ecoinvent 3.2 cutoff',
#   '16a27ff169b07598e90f90db76beb875'): ('bipyridylium-compound production', 'bipyridylium-compound'),
#  ('ecoinvent 3.2 cutoff',
#   'a9c7afa98a9240dc7c35675d75c8d5f3'): ('hydroformylation of butene', '2-methyl-1-butanol'),
#  ('ecoinvent 3.2 cutoff',
#   '08fff387c29203baabe18dcbb859af3f'): ('soybean meal and crude oil production, mechanical extraction', 'soybean oil, crude'),
#  ('ecoinvent 3.2 cutoff',
#   '03e20bd81bea25ef4cec474af92d23af'): ('market for heat, in chemical industry', 'heat, in chemical industry'),
#  ('ecoinvent 3.2 cutoff',
#   '11a88906a7657d188b5f94e4d22988a0'): ('silencer production, steel, DN 125', 'silencer, steel, DN 125'),
#  ('ecoinvent 3.2 cutoff',
#   '1fe138200c7888ffcbb7c25bd3986b02'): ('transport, freight train, electricity', 'transport, freight train'),
#  ('ecoinvent 3.2 cutoff',
#   '364bca80b2975f65a259f49787c293d4'): ('synthetic gas production, from wood, at fluidized bed gasifier', 'synthetic gas'),
#  ('ecoinvent 3.2 cutoff',
#   '213fde9c115fc7cc105c71a8e1df1550'): ('citric acid production', 'gypsum, mineral'),
#  ('ecoinvent 3.2 cutoff',
#   'a896ff556201b6fe3d78d41cb719b21f'): ('benzaldehyde production', 'benzaldehyde'),
#  ('ecoinvent 3.2 cutoff',
#   'daa030356973a56899142e2229fe52fa'): ('cast iron drilling, conventional', 'cast iron removed by drilling, conventional'),
#  ('ecoinvent 3.2 cutoff',
#   '8d430d99fc903a3c256645964ac844d7'): ('heat and power co-generation, wood chips, 6667 kW, state-of-the-art 2014', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '4f6d5f28acc2156118b973ca7cbad941'): ('treatment of used blower and heat exchange unit, Storkair G 90', 'used blower and heat exchange unit Storkair G 90'),
#  ('ecoinvent 3.2 cutoff',
#   '931406fe3bdf148a49b1fafef9847b2e'): ('cadmium chloride production, semiconductor-grade', 'cadmium chloride, semiconductor-grade'),
#  ('ecoinvent 3.2 cutoff',
#   '29d821e85390da17b58b90765fa43ddb'): ('extrusion of plastic sheets and thermoforming, inline', 'extrusion of plastic sheets and thermoforming, inline'),
#  ('ecoinvent 3.2 cutoff',
#   'a78613fe4a5e7e0c333998f3705b7d52'): ('port facilities construction', 'port facilities'),
#  ('ecoinvent 3.2 cutoff',
#   '45bcc4bbe3475b364d6dde224044c614'): ('extrusion, co-extrusion of plastic sheets', 'extrusion, co-extrusion'),
#  ('ecoinvent 3.2 cutoff',
#   '3dafeec68a5fdb4780f97a396d3df5cf'): ('softwood forestry, pine, sustainable forest management', 'sawlog and veneer log, softwood, measured as solid wood under bark'),
#  ('ecoinvent 3.2 cutoff',
#   'b5205916c98aa86660dd5c03cdf098bd'): ('ammonium carbonate production', 'ammonium carbonate'),
#  ('ecoinvent 3.2 cutoff',
#   '69af51bd98158d09d5f015183a26d569'): ('transport, freight, lorry 3.5-7.5 metric ton, EURO6', 'transport, freight, lorry 3.5-7.5 metric ton, EURO6'),
#  ('ecoinvent 3.2 cutoff',
#   '16271e43edb1edab1592c833d2101535'): ('anode production, graphite, for lithium-ion battery', 'anode, graphite, for lithium-ion battery'),
#  ('ecoinvent 3.2 cutoff',
#   '809cf595cb5dd8ed411977dbf99c7bcd'): ('treatment of waste cement-fibre slab, municipal incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '082f6633097076a07638852ca1ba140a'): ('operation, computer, desktop, with cathode ray tube display, off mode', 'operation, computer, desktop, with cathode ray tube display, off mode'),
#  ('ecoinvent 3.2 cutoff',
#   'd20ff4f8a9bedcc6d891c1b53284efc6'): ('treatment of waste, from silicon wafer production, underground deposit', 'waste, from silicon wafer production'),
#  ('ecoinvent 3.2 cutoff',
#   '62a113ce27da513bfe33ae2f14b29bb6'): ('wood chips production, hardwood, at sawmill', 'wood chips, wet, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   '9d5be80bd78547146615bcc6c2afa03b'): ('impact extrusion of steel, hot, tempering', 'impact extrusion of steel, hot, tempering'),
#  ('ecoinvent 3.2 cutoff',
#   '5c0f65702e7a4fbd5d311112466a3b40'): ('ethylene bromide production', 'ethylene bromide'),
#  ('ecoinvent 3.2 cutoff',
#   '08f1c6e195d247172bc3ebf806c65574'): ('chloronitrobenzene production', 'chloronitrobenzene'),
#  ('ecoinvent 3.2 cutoff',
#   '106ae1928e6128496b83393301e7352c'): ('molecular sieve separation of naphtha', 'heptane'),
#  ('ecoinvent 3.2 cutoff',
#   'bdc4a84397b96bb0fecc425e1ca96324'): ('transport, passenger car, large size, diesel, EURO 3', 'transport, passenger car, large size, diesel, EURO 3'),
#  ('ecoinvent 3.2 cutoff',
#   'ef80ca4f6335c4543de8ae47d3cd5fc0'): ('water storage construction', 'water storage'),
#  ('ecoinvent 3.2 cutoff',
#   '39727054ba038d782171a4bacc15c2a4'): ('green manure growing, organic, until January', 'green manure, organic, until January'),
#  ('ecoinvent 3.2 cutoff',
#   'f590f278587c44a16febc59f4f3b86df'): ('market for transport, freight train', 'transport, freight train'),
#  ('ecoinvent 3.2 cutoff',
#   '8cfb0f44859a415b6275f89438935650'): ('grass seed production, organic, for sowing', 'grass seed, organic, for sowing'),
#  ('ecoinvent 3.2 cutoff',
#   '5a7cc01419436bb61df1e517fff58675'): ('wire drawing, copper', 'wire drawing, copper'),
#  ('ecoinvent 3.2 cutoff',
#   '872b772ae88e278496d788cb4ad0e3c0'): ('ethanol production from wood', 'ethanol, without water, in 95% solution state, from fermentation'),
#  ('ecoinvent 3.2 cutoff',
#   '6afad539e4889ce43920f5bcd71574a7'): ('laser machining, metal, with YAG-laser, 200W power', 'laser machining, metal, with YAG-laser, 200W power'),
#  ('ecoinvent 3.2 cutoff',
#   '4c28f22de322b3eb3743887a2aff6354'): ('maintenance, bus', 'maintenance, bus'),
#  ('ecoinvent 3.2 cutoff',
#   '86d00ae03d2e412a3417e3989ffb3b78'): ('impact extrusion of steel, warm, initial warming', 'impact extrusion of steel, warm, initial warming'),
#  ('ecoinvent 3.2 cutoff',
#   '330deb762a424a7172776c2323f61d29'): ('oxidation of manganese dioxide', 'potassium permanganate'),
#  ('ecoinvent 3.2 cutoff',
#   '7800453ae350e4042b6f75243aabbe64'): ('silicon production, electronics grade', 'silicon, electronics grade'),
#  ('ecoinvent 3.2 cutoff',
#   '40984701ff375ae363ac7e37aec00117'): ('market for sawnwood, hardwood, dried (u=20%), planed', 'sawnwood, hardwood, dried (u=20%), planed'),
#  ('ecoinvent 3.2 cutoff',
#   '66a2e6047284ced4b3ad329964b340dc'): ('vegetable oil esterification facility construction', 'vegetable oil esterification facility'),
#  ('ecoinvent 3.2 cutoff',
#   '7a2a44e96412bf6d1c2596c606e0ae51'): ('cement production, blast furnace slag 31-50% and 31-50% other alternative constituents', 'cement, blast furnace slag 31-50% and 31-50% other alternative constituents'),
#  ('ecoinvent 3.2 cutoff',
#   '582d35fcc22462bca0edb19b79c3406a'): ('linerboard production, kraftliner', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   'cbc10c9fdb645d012ef15b625a7a7766'): ('natural gas production, liquefied', 'natural gas, liquefied'),
#  ('ecoinvent 3.2 cutoff',
#   '78b38e083932811781512418401ea52b'): ('wood preservation, dipping/immersion, solvent-based preservative, indoor use, dry', 'wood preservation, dipping/immersion method, organic solvent-based, indoor use, dry'),
#  ('ecoinvent 3.2 cutoff',
#   '674d2fe2825e142113b23ca71cfc3c58'): ('heat production, mixed logs, at furnace 30kW', 'heat, central or small-scale, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   'eddd2b622b11a99a8971ab81ceeda4d5'): ('sheet rolling, copper', 'sheet rolling, copper'),
#  ('ecoinvent 3.2 cutoff',
#   '7351dad63d2fee02ec85f22c6f6fb7ce'): ('market for electricity, high voltage, aluminium industry', 'electricity, high voltage, aluminium industry'),
#  ('ecoinvent 3.2 cutoff',
#   '201e3532daa79f3a0f87bccbd69dfb34'): ('treatment of residue from mechanical treatment, cathode ray tube display, municipal waste incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '2e786133b3f9126958099f643352c01c'): ('treatment of waste emulsion paint, municipal incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   'ef7ab04151882c4d3e1dc93c40b988be'): ('laser machining, metal, with CO2-laser, 5000W power', 'laser machining, metal, with CO2-laser, 5000W power'),
#  ('ecoinvent 3.2 cutoff',
#   '7c6133d52b28e608c91dcee8a2707de7'): ('photovoltaic flat-roof installation, 3kWp, single-Si, on roof', 'photovoltaic flat-roof installation, 3kWp, single-Si, on roof'),
#  ('ecoinvent 3.2 cutoff',
#   '2ce4d18280865687a146366644f7b413'): ('compressed air production, 800 kPa gauge, >30kW, average generation', 'compressed air, 800 kPa gauge'),
#  ('ecoinvent 3.2 cutoff',
#   '349d50012eaf1539205f7bfca2ed1159'): ('auxiliary heating unit production, electric, 5kW', 'auxiliary heating unit, electric, 5kW'),
#  ('ecoinvent 3.2 cutoff',
#   '7922d07e1e5541b1a5e4eea437359570'): ('metal working, average for aluminium product manufacturing', 'metal working, average for aluminium product manufacturing'),
#  ('ecoinvent 3.2 cutoff',
#   'c239e02a703c5df3bb8daf023f287dbf'): ('tetrafluoroethylene film production, on glass', 'tetrafluoroethylene film, on glass'),
#  ('ecoinvent 3.2 cutoff',
#   '98b14b3408dfb76ca31aaa2489f5ab69'): ('seal production, natural rubber based', 'seal, natural rubber based'),
#  ('ecoinvent 3.2 cutoff',
#   '6f820913b7f645cc0c862f95f6dc55d6'): ('operation, internet access equipment, label-certified electricity', 'operation, internet access equipment, label-certified electricity'),
#  ('ecoinvent 3.2 cutoff',
#   'bb033b7f5cc812834bb6092d8028e0c7'): ('treatment of waste paperboard, sanitary landfill', 'waste paperboard'),
#  ('ecoinvent 3.2 cutoff',
#   '6b673fbdbc62cdb6a6a1bf6a2e8dfd30'): ('catalytic converter production, oxidation, 20 litre', 'catalytic converter, oxidation, 20 litre'),
#  ('ecoinvent 3.2 cutoff',
#   'a12602b020a68e0ad80dbf1686b3843f'): ('natural gas, burned in micro gas turbine, 100kWe', 'heat, central or small-scale, natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '95438861c9c887e601141d57ad56f9a1'): ('polyethylene pipe production, DN 200, SDR 41', 'polyethylene pipe, DN 200, SDR 41'),
#  ('ecoinvent 3.2 cutoff',
#   'bb7b6776b79f166bda8a08f02e597d3d'): ('beet sugar production', 'sugar beet pulp'),
#  ('ecoinvent 3.2 cutoff',
#   '77eac3ef56c0ae19aaa38f2e22362589'): ('fatty alcohol sulfate production, petrochemical', 'fatty alcohol sulfate'),
#  ('ecoinvent 3.2 cutoff',
#   '9d3ebbe395d250b3157d3d100a2c6900'): ('catch crop growing, ryegrass-Egyptian&Persian clover-mixture, August-October, organic fertiliser 30 kg N, one cut', 'ryegrass-Egyptian&Persian clover-mixture silage'),
#  ('ecoinvent 3.2 cutoff',
#   '5696bab17f92d64e24dc0e938e32344e'): ('electricity production, wind, <1MW turbine, onshore', 'electricity, high voltage'),
#  ('ecoinvent 3.2 cutoff',
#   '155f10e674f6c7dba93ace8b0137fdba'): ('assembly of generator and motor, auxilliaries and energy use, heat and power co-generation unit, 160kW electrical', 'assembly of generator and motor, auxilliaries and energy use, for heat and power co-generation unit, 160 KW electrical'),
#  ('ecoinvent 3.2 cutoff',
#   '410930e3f044925f916c6b482ef7a65c'): ('pentaerythritol production in sodium hydroxide solution', 'pentaerythritol'),
#  ('ecoinvent 3.2 cutoff',
#   '73a3c360b07cb99bd340a24b80d17db5'): ('treatment of spent anion exchange resin from potable water production, municipal incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   'e0a21fd962fb8f5a25de35ea4b1cfd03'): ('p-chlorophenol production', 'p-chlorophenol'),
#  ('ecoinvent 3.2 cutoff',
#   '611b2cdd8c3e33cdd75fbaab7c46a4e5'): ('N-methyl-2-pyrrolidone production', 'N-methyl-2-pyrrolidone'),
#  ('ecoinvent 3.2 cutoff',
#   'e252fa9af762e3c5b50c0226d77f27e2'): ('sweet gas, burned in gas turbine', 'sweet gas, burned in gas turbine'),
#  ('ecoinvent 3.2 cutoff',
#   'a1e94f5a767621e7ddb698062d5ae4cb'): ('corrugated board box production', 'residual softwood, wet'),
#  ('ecoinvent 3.2 cutoff',
#   '68852552be3ec6538c07f9aa4874e377'): ('market for sawnwood, hardwood, raw, dried (u=10%)', 'sawnwood, hardwood, raw, dried (u=10%)'),
#  ('ecoinvent 3.2 cutoff',
#   '03b69724726c250ccefb27f62f3a938b'): ('aluminium alloy production, AlLi', 'copper'),
#  ('ecoinvent 3.2 cutoff',
#   'd79b751c0e741bdf53113b4b5a4aa838'): ('printing ink production, rotogravure, product in 55% toluene solution state', 'printing ink, rotogravure, without solvent, in 55% toluene solution state'),
#  ('ecoinvent 3.2 cutoff',
#   'f85232fb468d00c5236093290ae032e5'): ('dimethyl sulfoxide production', 'dimethyl sulfoxide'),
#  ('ecoinvent 3.2 cutoff',
#   '57f30abe5c04ad598906183461986a1f'): ('ethanolamine production', 'monoethanolamine'),
#  ('ecoinvent 3.2 cutoff',
#   'ad56bb6afd15bcc3e603a2bce1ebfa0d'): ('treatment of waste wood, untreated, municipal incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '3e1efa71792658e73857a08c76402c97'): ('market for petrol, low-sulfur', 'petrol, low-sulfur'),
#  ('ecoinvent 3.2 cutoff',
#   'a51f9b4a07ad7f83ab33105a8a581518'): ('pyridine-compound production', 'pyridine-compound'),
#  ('ecoinvent 3.2 cutoff',
#   'd5919cf8ead121bd959ab85292f20bed'): ('market for municipal solid waste', 'municipal solid waste'),
#  ('ecoinvent 3.2 cutoff',
#   '1b5cf4bc491f6be491c8b7b476fce0cb'): ('photovoltaic cell production, multi-Si wafer', 'photovoltaic cell, multi-Si wafer'),
#  ('ecoinvent 3.2 cutoff',
#   '3e3f749796f90b83bb394170f421d6b5'): ('heavy mineral sand quarry operation', 'rutile, 95% titanium dioxide'),
#  ('ecoinvent 3.2 cutoff',
#   'eb53cd41efb3d97a319147d5cb5f6cfb'): ('ethoxylated alcohol (AE7) production, palm kernel oil', 'ethoxylated alcohol (AE7)'),
#  ('ecoinvent 3.2 cutoff',
#   '48243d8c027a1e3e6d1a57a6b84db8af'): ('haying, by rotary tedder', 'haying, by rotary tedder'),
#  ('ecoinvent 3.2 cutoff',
#   'be19a2812e460d5e2ea830d9d5a8b977'): ('feldspar production', 'feldspar'),
#  ('ecoinvent 3.2 cutoff',
#   '293bbf9aab173becd0d8022d95a3f597'): ('2,4-dichlorotoluene production',
#   '2,4-dichlorotoluene'),
#  ('ecoinvent 3.2 cutoff',
#   '20fcea0899d31dbf5d7f027cd133ef99'): ('zinc sulfide production', 'zinc sulfide'),
#  ('ecoinvent 3.2 cutoff',
#   'a57ea6af4a2c3d761832e440beef089d'): ('particle board production, for outdoor use', 'particle board, for outdoor use'),
#  ('ecoinvent 3.2 cutoff',
#   '4376e2f8d6727c31d3dad1efd9273b0b'): ('collection of polystyrene scrap, post-consumer', 'polystyrene scrap, post-consumer'),
#  ('ecoinvent 3.2 cutoff',
#   '68ae7be88735ef5be79d63eea977bf91'): ('hydrochloric acid production, from the reaction of hydrogen with chlorine', 'hydrochloric acid, without water, in 30% solution state'),
#  ('ecoinvent 3.2 cutoff',
#   '12e7fb636b8abf1f8de4aa9cebc40012'): ('transport, passenger, aircraft, intracontinental', 'transport, passenger, aircraft'),
#  ('ecoinvent 3.2 cutoff',
#   'd226c9648d96865f51a6bf4b575ace26'): ('hydrogen sulfide production', 'hydrogen sulfide'),
#  ('ecoinvent 3.2 cutoff',
#   '1c99f57e494f22ad5e5ea0692e98163b'): ('heat production, wood pellet, at furnace 25kW, state-of-the-art 2014', 'heat, central or small-scale, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   'cabefe651d3212cfc339dbcee17bea92'): ('gas motor production, mini CHP plant', 'gas motor, mini CHP plant'),
#  ('ecoinvent 3.2 cutoff',
#   '1410c9913fc7ced4f889d7c9d6f554d0'): ('steam production in chemical industry', 'heat, in chemical industry'),
#  ('ecoinvent 3.2 cutoff',
#   '99bf5376aece47e55799b34bd1c6d067'): ('softwood forestry, pine, sustainable forest management', 'cleft timber, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   '044dca76fb77b24d8eb64a831cdc35d7'): ('petroleum refinery construction', 'petroleum refinery'),
#  ('ecoinvent 3.2 cutoff',
#   '0b16b93f41bd0ea1eaed28931bee898c'): ('selective coating, copper sheet, physical vapour deposition', 'selective coat, copper sheet, physical vapour deposition'),
#  ('ecoinvent 3.2 cutoff',
#   '452ce3af99c2a88dfd83b9b30be0283b'): ('market for wood pellet', 'wood pellet, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   'fcb6f3949a2c8b4bbc7b7b8bb8e973a4'): ('copper production, from imported concentrates', 'copper'),
#  ('ecoinvent 3.2 cutoff',
#   '7bf77932377510d1599eb2e95cd5f901'): ('market for pulpwood, hardwood, measured as solid wood under bark', 'pulpwood, hardwood, measured as solid wood under bark'),
#  ('ecoinvent 3.2 cutoff',
#   '0323f25b5a39b91f6ecf41aaa62c13a5'): ('forging, steel, large open die', 'forging, steel'),
#  ('ecoinvent 3.2 cutoff',
#   'cdcd03a06dc32b3f1a149137a6bd7c83'): ('copper mine operation', 'copper concentrate'),
#  ('ecoinvent 3.2 cutoff',
#   'f1ff3df54ea16aff1886abdc36abc77d'): ('sodium borates production', 'sodium borates'),
#  ('ecoinvent 3.2 cutoff',
#   '21d94ac7ca13db17e2382419261d801f'): ('beam, softwood, raw, air drying to u=20%', 'sawnwood, beam, softwood, raw, dried (u=20%)'),
#  ('ecoinvent 3.2 cutoff',
#   '6bddd30234a56997465400c3e5c461a1'): ('treatment of waste expanded polystyrene, municipal incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   'a72aa0b8c23975cf9c1e3e9de57fe655'): ('spodumene production', 'spodumene'),
#  ('ecoinvent 3.2 cutoff',
#   '611c469db1bc8bfd3f7ce06b57002cbb'): ('aluminium oxide factory construction',
#   'aluminium oxide factory'),
#  ('ecoinvent 3.2 cutoff',
#   'e4d08c274bef238dc930b389bd1b443c'): ('paper production, woodfree, coated, at non-integrated mill', 'paper, woodfree, coated'),
#  ('ecoinvent 3.2 cutoff',
#   'b9cf8e26e46425e124d4ea44c15178b5'): ('metallization paste production, front side', 'metallization paste, front side'),
#  ('ecoinvent 3.2 cutoff',
#   'e011a4e7e62476729a89ec403b1f9327'): ('treatment of waste polyethylene, sanitary landfill', 'waste polyethylene'),
#  ('ecoinvent 3.2 cutoff',
#   'd0d4f354650a2e466468b34263ea4276'): ('treatment of road wear emissions, passenger car', 'road wear emissions, passenger car'),
#  ('ecoinvent 3.2 cutoff',
#   'a206978d16a4f439aea1c45ec1682211'): ('multi-Si wafer production, ribbon', 'multi-Si wafer, ribbon'),
#  ('ecoinvent 3.2 cutoff',
#   '3d41fef73239e096763918b379b3c345'): ('treatment of residue from mechanical treatment, IT accessory, municipal waste incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '69bcbb8e5e3645204048ebe86e05076c'): ('sodium nitrite production', 'sodium nitrite'),
#  ('ecoinvent 3.2 cutoff',
#   '96f6652e80dcd95c69736c4898acbef8'): ('transport, tram', 'transport, tram'),
#  ('ecoinvent 3.2 cutoff',
#   '0ddef8535028524eabe68905a67c0275'): ('vinyl fluoride production',
#   'hydrogen fluoride'),
#  ('ecoinvent 3.2 cutoff',
#   'f0d0ded84f13aa8d134241b89c5d05fd'): ('wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact', 'wood preservation, oscillating pressure method, organic salt, Cr-free, outdoor use, ground contact'),
#  ('ecoinvent 3.2 cutoff',
#   '00528ecc898dab2969574e18a2c88314'): ('sewer grid construction, 1.6E8l/year, 6 km', 'sewer grid, 1.6E8l/year, 6 km'),
#  ('ecoinvent 3.2 cutoff',
#   '5688d3ec3f5238838716302b1de6dd1e'): ('transport, freight, lorry 28 metric ton, vegetable oil methyl ester 100%', 'transport, freight, lorry 28 metric ton, vegetable oil methyl ester 100%'),
#  ('ecoinvent 3.2 cutoff',
#   'b1f1a216e2905b5f70a25eaf10d07f8c'): ('blower and heat exchange unit production, decentralized, 180-250 m3/h', 'blower and heat exchange unit, decentralized, 180-250 m3/h'),
#  ('ecoinvent 3.2 cutoff',
#   'c385129f22bfbe99f3861a1271cff56b'): ('energy and auxilliary inputs, metal working machine, with process heat from light fuel oil', 'energy and auxilliary inputs, metal working machine'),
#  ('ecoinvent 3.2 cutoff',
#   'b57d93b8eb4b5714ab95e0d146f2842a'): ('furnace production, wood chips, with silo, 300kW', 'furnace, wood chips, with silo, 300kW'),
#  ('ecoinvent 3.2 cutoff',
#   'f1d1509a45ac8c241f578a593c12e9b8'): ('treatment of biogas, purification to methane 96 vol-%', 'methane, 96% by volume'),
#  ('ecoinvent 3.2 cutoff',
#   '53bdbda72eb71f073e65d7ee3a70f3ea'): ('planning, heat and power co-generation unit, 160kW electrical', 'planning, heat and power co-generation unit, 160kW electrical'),
#  ('ecoinvent 3.2 cutoff',
#   '0f140fbac5b443c0e6481d8377c960a3'): ('aircraft production, long haul', 'aircraft, long haul'),
#  ('ecoinvent 3.2 cutoff',
#   'c0b7bd0d4b9c795f33af9f11269a4ac7'): ('green manure growing, Swiss integrated production, until April', 'green manure, Swiss integrated production, until April'),
#  ('ecoinvent 3.2 cutoff',
#   '025b3040e68c05426ebcada6e76e6cc7'): ('market for maleic anhydride', 'maleic anhydride'),
#  ('ecoinvent 3.2 cutoff',
#   'e5505b4f0170206d4361851bd9698808'): ('stone groundwood pulp production', 'stone groundwood pulp'),
#  ('ecoinvent 3.2 cutoff',
#   'b4c784a5d81edd890c5bb167ab451389'): ('delimbing, with excavator-based processor', 'delimbing/sorting, excavator-based processor'),
#  ('ecoinvent 3.2 cutoff',
#   '278ca62b452138dfc83f0153bcbd6a6b'): ('grass silage production, organic', 'grass silage, organic'),
#  ('ecoinvent 3.2 cutoff',
#   '812e6d13a2ee1610dea370f0d27e5847'): ('harvesting/bundling, energy wood harvester', 'harvesting/bundling, energy wood harvester'),
#  ('ecoinvent 3.2 cutoff',
#   'cbb983f865d556734523cfc9efba53af'): ('primary zinc production from concentrate', 'sulfuric acid'),
#  ('ecoinvent 3.2 cutoff',
#   'b1377160daa4887344248bf18a12e2f4'): ('trifluoroacetic acid production', 'trifluoroacetic acid'),
#  ('ecoinvent 3.2 cutoff',
#   'ade724af5f5ec641e2455abd2d85fb8b'): ('treatment of wood ash mixture, pure, sanitary landfill', 'wood ash mixture, pure'),
#  ('ecoinvent 3.2 cutoff',
#   'ab0500c41fc99c35de173adef5cc3c87'): ('primary zinc production from concentrate', 'sulfur dioxide, liquid'),
#  ('ecoinvent 3.2 cutoff',
#   '0452a92de55d409f1c6ea0d6d956a3af'): ('hard coal briquettes production', 'hard coal briquettes'),
#  ('ecoinvent 3.2 cutoff',
#   '19dd0f00952ed1d601ddac3ec475771a'): ('assembly of generator and motor, auxilliaries and energy use, for mini CHP plant', 'assembly of generator and motor, auxilliaries and energy use, for mini CHP plant'),
#  ('ecoinvent 3.2 cutoff',
#   'ef7f5183de45bdc3825e5f91bf63e8d3'): ('clinker production', 'waste wood, untreated'),
#  ('ecoinvent 3.2 cutoff',
#   'ddf1bd9091c5a2791253dd5ab45c8014'): ('rock wool production', 'rock wool'),
#  ('ecoinvent 3.2 cutoff',
#   'b511ebd57024cb0298bc555947a8c750'): ('heat and power co-generation, oil',
#   'electricity, high voltage'),
#  ('ecoinvent 3.2 cutoff',
#   '128052608eb390ee55206291940c1d5f'): ('heat and power co-generation unit construction, 200kW electrical, diesel SCR, common components for heat+electricity', 'heat and power co-generation unit, 200kW electrical, diesel SCR, common components for heat+electricity'),
#  ('ecoinvent 3.2 cutoff',
#   '936cb6f5f2e362765d488e524d8d9f0f'): ('operation, computer, desktop, with cathode ray tube display, standby mode', 'operation, computer, desktop, with cathode ray tube display, standby mode'),
#  ('ecoinvent 3.2 cutoff',
#   '23fb8fb2f807a87d2d913645a117e5e2'): ('treatment of used electric bicycle', 'used electric bicycle'),
#  ('ecoinvent 3.2 cutoff',
#   'd65e9665d9c154dea5d1aa462016859f'): ('mine construction, open cast, lignite', 'mine infrastructure, open cast, lignite'),
#  ('ecoinvent 3.2 cutoff',
#   '99faeb70c1dbb19ca74591ca83264c8e'): ('soap production', 'soap'),
#  ('ecoinvent 3.2 cutoff',
#   '2a5974db68184cdc3eeaaac96bec4fe7'): ('diazine-compound production',
#   'diazine-compound'),
#  ('ecoinvent 3.2 cutoff',
#   '6accb5162881efe539b0661904fcf94f'): ('ethanol production from whey', 'ethanol, without water, in 95% solution state, from fermentation'),
#  ('ecoinvent 3.2 cutoff',
#   'a55c3ea3cafae4918b6554e63c0396d1'): ('swath, by rotary windrower', 'swath, by rotary windrower'),
#  ('ecoinvent 3.2 cutoff',
#   '9ee95cb57c674fef7b73b2becf2c9f79'): ('market for ozone, liquid', 'ozone, liquid'),
#  ('ecoinvent 3.2 cutoff',
#   '1bc84f0e02e2f8aeffc058c10ae9f9aa'): ('nuclear waste storage construction, final repository for high level radioactive waste', 'nuclear waste storage, final repository for high level radioactive waste'),
#  ('ecoinvent 3.2 cutoff',
#   'ab08591f746eea510f80ace274d11796'): ('magnesium oxide production', 'magnesium oxide'),
#  ('ecoinvent 3.2 cutoff',
#   'c18d6b381cf875ac4de465d8e08c6d03'): ('palm fruit bunch production, on land recently transformed', 'palm fruit bunch'),
#  ('ecoinvent 3.2 cutoff',
#   '9f2ad139b42810194a54f2cb07469087'): ('maintenance, mini CHP plant', 'maintenance, mini CHP plant'),
#  ('ecoinvent 3.2 cutoff',
#   'ef196e6ada2448448010f5c8e2a1450e'): ('treatment of waste glass, municipal incineration', 'waste glass'),
#  ('ecoinvent 3.2 cutoff',
#   'd80c7395d68188bfe96f5414b156b846'): ('heat and power co-generation unit construction, 200kW electrical, diesel SCR, components for electricity only', 'heat and power co-generation unit, 200kW electrical, diesel SCR, components for electricity only'),
#  ('ecoinvent 3.2 cutoff',
#   'bfcfd2ad5467fd56900cfb20368b18ae'): ('treatment of waste wire plastic, municipal incineration', 'waste wire plastic'),
#  ('ecoinvent 3.2 cutoff',
#   'd801736a2165d2240035e9af1a155825'): ('soybean production', 'soybean'),
#  ('ecoinvent 3.2 cutoff',
#   'd47da43239bda08c7bab05476dcfef53'): ('market for plywood, for outdoor use',
#   'plywood, for outdoor use'),
#  ('ecoinvent 3.2 cutoff',
#   '1ef886c5d9e20c45cead6349343f3c84'): ('wind turbine construction, 750kW, onshore', 'wind turbine, 750kW, onshore'),
#  ('ecoinvent 3.2 cutoff',
#   '947b85980ebca2a74ffd39ac61459587'): ('treatment of inert waste, inert material landfill', 'inert waste, for final disposal'),
#  ('ecoinvent 3.2 cutoff',
#   '03352f262b4e0269a379fde0b6757491'): ('electricity production, photovoltaic, 3kWp slanted-roof installation, ribbon-Si, panel, mounted', 'electricity, low voltage'),
#  ('ecoinvent 3.2 cutoff',
#   '4a305a7526e49561863518432b1978b6'): ('urea formaldehyde resin production', 'urea formaldehyde resin'),
#  ('ecoinvent 3.2 cutoff',
#   'ec4d7674ffc9c7c4e6dc305ff90c586f'): ('ethanol production from sweet sorghum', 'ethanol, without water, in 95% solution state, from fermentation'),
#  ('ecoinvent 3.2 cutoff',
#   'd455bfe6f592620b3990c996111a8c8b'): ('silica sand production', 'silica sand'),
#  ('ecoinvent 3.2 cutoff',
#   'a71485a9aecde9ba7ddcdc7a156be30a'): ('wood pellet factory production', 'wood pellet factory'),
#  ('ecoinvent 3.2 cutoff',
#   '1f08d4169c98fec7151f909272816b4c'): ('milking parlour construction', 'milking parlour'),
#  ('ecoinvent 3.2 cutoff',
#   'd30f894968bf955cef66e0fde24c5173'): ('ethylene glycol production', 'triethylene glycol'),
#  ('ecoinvent 3.2 cutoff',
#   '0fcbdf3743266ecb33c60fb77013db5a'): ('melamine formaldehyde resin production', 'melamine formaldehyde resin'),
#  ('ecoinvent 3.2 cutoff',
#   '8b1edb36372828ca509a23d2923ee15f'): ('iron(III) chloride production, without water, in 12% iron solution state', 'iron(III) chloride, without water, in a 12% iron solution state'),
#  ('ecoinvent 3.2 cutoff',
#   'edee88dfad1a6f1ccbeca0c69a92f76d'): ('polyvinylidenchloride production, granulate', 'polyvinylidenchloride, granulate'),
#  ('ecoinvent 3.2 cutoff',
#   'a0e650f1a4ee6b78f7dca00e5728e6af'): ('explosive production, tovex', 'explosive, tovex'),
#  ('ecoinvent 3.2 cutoff',
#   'c50694260a51e06f63a07f12c4d229b5'): ('transport, passenger car', 'transport, passenger car'),
#  ('ecoinvent 3.2 cutoff',
#   '80ec335ffd53f9800c15464df5436b2d'): ('impact extrusion of steel, hot, deformation stroke', 'impact extrusion of steel, hot, deformation stroke'),
#  ('ecoinvent 3.2 cutoff',
#   '39b96eefe539768d469d5289b91c51aa'): ('treatment of residue from mechanical treatment, IT accessory, municipal waste incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   'b067145af35127a4ba2b2983367101e5'): ('catch crop growing, ryegrass, September-April, organic fertiliser 60 kg N, one cut', 'ryegrass silage'),
#  ('ecoinvent 3.2 cutoff',
#   '3be0314a358bee287b888deb650904dc'): ('carboxymethyl cellulose production, powder', 'carboxymethyl cellulose, powder'),
#  ('ecoinvent 3.2 cutoff',
#   '6b02a68d9ff15864ff0f5cb8c791118a'): ('planing, lath, softwood, u=10%', 'sawnwood, lath, softwood, dried (u=10%), planed'),
#  ('ecoinvent 3.2 cutoff',
#   '74b2b20cf3670274b2a15e8a35d3c9df'): ('impact extrusion of aluminium, 1 stroke', 'impact extrusion of aluminium, 1 stroke'),
#  ('ecoinvent 3.2 cutoff',
#   'd687437399fe6880a1c57df09941ea5e'): ('photovoltaic mounting system production, for slanted-roof installation', 'photovoltaic mounting system, for slanted-roof installation'),
#  ('ecoinvent 3.2 cutoff',
#   '1a4689092d184a66f6f6201a656b1162'): ('gravel/sand quarry construction', 'gravel/sand quarry infrastructure'),
#  ('ecoinvent 3.2 cutoff',
#   '92482b6d384185e6197bde1a6b45fd1b'): ('aluminium electrolysis facility construction', 'aluminium electrolysis facility'),
#  ('ecoinvent 3.2 cutoff',
#   '6884cefad056ff09ab5647059ad296d5'): ('road maintenance', 'road maintenance'),
#  ('ecoinvent 3.2 cutoff',
#   '676508f0cf04a4e7c482c0764c320f07'): ('heat and power co-generation unit construction, 200kW electrical, diesel SCR, components for heat only', 'heat and power co-generation unit, 200kW electrical, diesel SCR, components for heat only'),
#  ('ecoinvent 3.2 cutoff',
#   '69ef0745a1c6d55682b8e7f4e4e10810'): ('packaging glass sorting facility construction', 'packaging glass sorting facility'),
#  ('ecoinvent 3.2 cutoff',
#   'df4089c8cbeb3147eebc4f1de5427023'): ('nylon 6 production, glass-filled', 'nylon 6, glass-filled'),
#  ('ecoinvent 3.2 cutoff',
#   'ff00e8f2d9e36cea82725a454b9fb59a'): ('heat production, propane, at industrial furnace >100kW', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '2ef4a4e6f082edf52030ef6daa6338c9'): ('heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '2588fad6e0ab338504b0246b4f88aa50'): ('treatment of waste polyethylene, municipal incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '7e3668d02949db2b3e59a9852a087cbb'): ('molecular sieve separation of naphtha', '1,1-dimethylcyclopentane'),
#  ('ecoinvent 3.2 cutoff',
#   'e7215096dfdf88f2ed873136616a39ed'): ('chromium steel turning, primarily dressing, conventional', 'chromium steel removed by turning, primarily dressing, conventional'),
#  ('ecoinvent 3.2 cutoff',
#   '836b8270c99db33ad4d47f1d420c370d'): ('sawing, softwood', 'sawnwood, softwood, raw'),
#  ('ecoinvent 3.2 cutoff',
#   '7a6156d791d9c8fb9e53c6b2a2caf8e5'): ('treatment of recovered paper to fluting medium, wellenstoff', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '05ef9c93d98b5e8fe31365635e78110e'): ('rock crushing', 'rock crushing'),
#  ('ecoinvent 3.2 cutoff',
#   '5aef535a0ec77ba109a14a45b2796acb'): ('fuel cell production, stack polymer electrolyte membrane, 2kW electrical, future',
#   'fuel cell, stack polymer electrolyte membrane, 2kW electrical, future'),
#  ('ecoinvent 3.2 cutoff',
#   'd73e329c49a2f9a1ff3dcf0cdb62252e'): ('bitumen adhesive compound production, hot', 'bitumen adhesive compound, hot'),
#  ('ecoinvent 3.2 cutoff',
#   '4b9029f07d40e42698749bbfa31320c6'): ('treatment of waste glass, municipal incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '0d282e09b0757362f3def9e5cebdde9c'): ('insulation spiral-seam duct production, rockwool, DN 400, 30 mm', 'insulation spiral-seam duct, rockwool, DN 400, 30 mm'),
#  ('ecoinvent 3.2 cutoff',
#   '142b7b8f96189fd0de1d2336f45491a8'): ('chlorine dioxide production', 'chlorine dioxide'),
#  ('ecoinvent 3.2 cutoff',
#   '63c6877c87b629c7898325d199e21651'): ('tin plated chromium steel sheet production, 2 mm', 'tin plated chromium steel sheet, 2 mm'),
#  ('ecoinvent 3.2 cutoff',
#   '09d2f124d9da05fef8afbd33f9bfa58e'): ('transport, freight, lorry 7.5-16 metric ton, EURO3', 'transport, freight, lorry 7.5-16 metric ton, EURO3'),
#  ('ecoinvent 3.2 cutoff',
#   '0a481f2cc0e035f0b4860304c7db910d'): ('calcareous marl production', 'calcareous marl'),
#  ('ecoinvent 3.2 cutoff',
#   '34cc38a6b0a11c104a15d26fc1c66554'): ('anhydrite production, burned', 'anhydrite, burned'),
#  ('ecoinvent 3.2 cutoff',
#   '00f0dfc67659c95ceffe9182955bb157'): ('polyvinylchloride production, bulk polymerisation', 'polyvinylchloride, bulk polymerised'),
#  ('ecoinvent 3.2 cutoff',
#   'f35329428c78be0f13302e41c6b373fa'): ('air compressor production, screw-type compressor, 300kW', 'air compressor, screw-type compressor, 300kW'),
#  ('ecoinvent 3.2 cutoff',
#   '21608eae89017c0daeea47d59e82ef63'): ('impact extrusion of steel, hot, 4 strokes', 'impact extrusion of steel, hot, 4 strokes'),
#  ('ecoinvent 3.2 cutoff',
#   '10be0ab6c88130ab2b1fa46313a364e9'): ('diesel-electric generating set production 10MW production', 'diesel-electric generating set, 10MW'),
#  ('ecoinvent 3.2 cutoff',
#   '4ef0e2586e4c6e41e773d5e37b965594'): ('photovoltaic slanted-roof installation, 3kWp, a-Si, laminated, integrated, on roof', 'photovoltaic slanted-roof installation, 3kWp, a-Si, laminated, integrated, on roof'),
#  ('ecoinvent 3.2 cutoff',
#   'a4ca95c9f929dbd73cc9520c90c65f7d'): ('sodium chloride production, brine solution', 'sodium chloride, brine solution'),
#  ('ecoinvent 3.2 cutoff',
#   'ed0139b16b77b64c3eafa8fdb303e30a'): ('nylon 6-6 production, glass-filled', 'nylon 6-6, glass-filled'),
#  ('ecoinvent 3.2 cutoff',
#   '195ab58395841caf8fb314e711e61454'): ('deep drawing, steel, 650 kN press, automode', 'deep drawing, steel, 650 kN press, automode'),
#  ('ecoinvent 3.2 cutoff',
#   '5b01e1efdcdf99dcea7be3c1b494de46'): ('waste collection lorry production, 21 metric ton', 'waste collection lorry, 21 metric ton'),
#  ('ecoinvent 3.2 cutoff',
#   '00a0b327fb386b23ec64872009d65ec0'): ('uranium fuel element production, enriched 4%, for light water reactor', 'uranium, enriched 4%, in fuel element for light water reactor'),
#  ('ecoinvent 3.2 cutoff',
#   'ee7c65085707881c720f910565ee0bff'): ('treatment of spent anion exchange resin from potable water production, municipal incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   'ef2b54057bc7ff6317868485bf6f2bf8'): ('aluminium hydroxide factory construction', 'aluminium hydroxide factory'),
#  ('ecoinvent 3.2 cutoff',
#   '604d94f4ee496e5389227c3ea1d109f9'): ('treatment of waste sealing sheet, polyethylene, municipal incineration', 'heat, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '2aa7cbd7eec9a5fe0253c9f9e3965a2c'): ('gypsum quarry operation', 'gypsum, mineral'),
#  ('ecoinvent 3.2 cutoff',
#   '006d48f43e0ab1e1b14dbe80845d44d7'): ('treatment of waste emulsion paint, sanitary landfill', 'waste emulsion paint'),
#  ('ecoinvent 3.2 cutoff',
#   'de790e1af22dcd9214dc5947aa59c165'): ('fibreboard production, hard', 'fibreboard, hard'),
#  ('ecoinvent 3.2 cutoff',
#   '3f770b0d148d622773aecff5315cf08d'): ('glued laminated timber production, for indoor use', 'glued laminated timber, for indoor use'),
#  ('ecoinvent 3.2 cutoff',
#   '16cf954bb7bd4521959eb2fecf190fb5'): ('uranium production, enriched 4.2%, centrifugal enrichment', 'enriched uranium, 4.2%'),
#  ('ecoinvent 3.2 cutoff',
#   'ff0bd584a082a672e372b671643fbb5c'): ('treatment of used window frame, wood-metal, collection for final disposal', 'used window frame, wood-metal'),
#  ('ecoinvent 3.2 cutoff',
#   '3ef4303bdf18714ee08d020848528ce0'): ('expanded vermiculite production', 'expanded vermiculite'),
#  ('ecoinvent 3.2 cutoff',
#   '4483728434c158615eb312e65b56fb7a'): ('tree seedling production, in heated greenhouse', 'tree seedling'),
#  ('ecoinvent 3.2 cutoff',
#   'a10b9ab926b5a50fc461d05d8a2160c9'): ('brass turning, average, conventional', 'brass removed by turning, average, conventional'),
#  ('ecoinvent 3.2 cutoff',
#   '9f9db27a85ae04ca4ecc763f51ee5639'): ('treatment of waste paint, municipal incineration', 'waste paint'),
#  ('ecoinvent 3.2 cutoff',
#   '92875a7c6c03e50e094019ccc5697902'): ('sound insulation construction, heat and power co-generation unit, 160kW electrical', 'sound insulation, heat and power co-generation unit, 160kW electrical'),
#  ('ecoinvent 3.2 cutoff',
#   '7b415d4eb7f977b4792a6e9cb92d4552'): ('furnace production, wood chips, average storage area, 300kW', 'furnace, wood chips, average storage area, 300kW'),
#  ('ecoinvent 3.2 cutoff',
#   'adc6d5e9f25a3290f9db4e39c555aa53'): ('petroleum refinery operation', 'light fuel oil'),
#  ('ecoinvent 3.2 cutoff',
#   'd1931dde8925ff73752626f59a01eb0f'): ('treatment of waste packaging paper, municipal incineration', 'electricity, for reuse in municipal waste incineration only'),
#  ('ecoinvent 3.2 cutoff',
#   '5203f279b233700b1329948a698eb8d5'): ('cane sugar production with ethanol by-product', 'sugar, from sugarcane'),
#  ('ecoinvent 3.2 cutoff',
# ...
#  ('ecoinvent 3.2 cutoff',
#   'aace00e5312c36658e9a58f211bda481'): ('transport, trolleybus', 'transport, trolleybus'),
#  ('ecoinvent 3.2 cutoff',
#   '4e572ee324c3338f44390f2a20715eae'): ('ethoxylated alcohol (AE3) production, petrochemical', 'ethoxylated alcohol (AE3)'),
#  ('ecoinvent 3.2 cutoff',
#   '7acd2697274c662f0e4dd4b18ccb3cd9'): ('wood preservation, dipping/immersion, solvent-based preservative, indoor use, occasionally wet', 'wood preservation, dipping/immersion method, organic solvent-based, indoor use, occasionally wet'),
#  ('ecoinvent 3.2 cutoff',
#   'd3dcb86d28711e34ae3de3be8ee5bfe1'): ('ethylene hydration', 'diethyl ether, without water, in 99.95% solution state'),
#  ('ecoinvent 3.2 cutoff',
#   '7e6ae259ecf20714fe9a20c3fb07e727'): ('heat production, hardwood chips from forest, at furnace 300kW', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '2399abb6eb806f59819ace4383a21d35'): ('treatment of decommissioned pipeline, natural gas, inert material landfill', 'decommissioned pipeline, natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '1038b652ad0b02e15b2618372a11f561'): ('building construction, multi-storey', 'building, multi-storey'),
#  ('ecoinvent 3.2 cutoff',
#   'f0b8798d841eaf72f0fde4d3395253fd'): ('photovoltaic slanted-roof installation, 3kWp, single-Si, laminated, integrated, on roof', 'photovoltaic slanted-roof installation, 3kWp, single-Si, laminated, integrated, on roof'),
#  ('ecoinvent 3.2 cutoff',
#   'c4954148734dd808d9cdc54300d2792c'): ('glyphosate production', 'glyphosate'),
#  ('ecoinvent 3.2 cutoff',
#   '99d30fb5b4a070857d4ba23e3babb7af'): ('hardwood forestry, meranti, sustainable forest management',
#   'roundwood, meranti from sustainable forest management, under bark'),
#  ('ecoinvent 3.2 cutoff',
#   'c6aa8278c902d4e781737367f7fe9a87'): ('electricity production, oil', 'electricity, high voltage'),
#  ('ecoinvent 3.2 cutoff',
#   '49ba17eddc55bc967a8dd9f5e4370c10'): ('uranium production, diffusion, enriched 4.0%', 'uranium, enriched 4.0%, per separative work unit'),
#  ('ecoinvent 3.2 cutoff',
#   '50958bba57c0e76c17f745b869342ba4'): ('blower and heat exchange unit production, Storkair G 90', 'blower and heat exchange unit, Storkair G 90'),
#  ('ecoinvent 3.2 cutoff',
#   '9caa1a11dff6091172619305dda4ca84'): ('inverter production, 2.5kW', 'inverter, 2.5kW'),
#  ('ecoinvent 3.2 cutoff',
#   '8310dc9172c9b0cb6e896afb2f5a20fe'): ('operation, computer, desktop, with liquid crystal display, active mode', 'operation, computer, desktop, with liquid crystal display, active mode'),
#  ('ecoinvent 3.2 cutoff',
#   'a9575fa68bfde9c03fc5c6d9e2128fb7'): ('glass fibre production', 'glass fibre'),
#  ('ecoinvent 3.2 cutoff',
#   '8d63833fd00b3ae61e37ba26108a57a8'): ('impact extrusion of steel, cold, deformation stroke', 'impact extrusion of steel, cold, deformation stroke'),
#  ('ecoinvent 3.2 cutoff',
#   'e41d3cb6b9efe511313bf421302bf063'): ('treatment of spent catalytic converter for cars, underground deposit', 'spent catalytic converter for cars'),
#  ('ecoinvent 3.2 cutoff',
#   '6acbbe8eebdb45ec767853f9ae846753'): ('steel turning, average, conventional', 'steel removed by turning, average, conventional'),
#  ('ecoinvent 3.2 cutoff',
#   '540a79bec7777ba7042e50ceda435924'): ('furnace production, wood chips, hardwood storage area, 1000kW', 'furnace, wood chips, hardwood storage area, 1000kW'),
#  ('ecoinvent 3.2 cutoff',
#   'be90e05dc9c6118b7a5352e2cc31515e'): ('synthetic gas production, from wood, at fixed bed gasifier', 'synthetic gas'),
#  ('ecoinvent 3.2 cutoff',
#   '1c2ffaa6f970d4720ea038e80e7a5435'): ('2,4-dichlorophenol production', '2,4-dichlorophenol'),
#  ('ecoinvent 3.2 cutoff',
#   '8bc6a6ead8a4132e98339131b440a875'): ('heat and power co-generation unit construction, 1MW electrical, components for electricity only', 'heat and power co-generation unit, 1MW electrical, components for electricity only'),
#  ('ecoinvent 3.2 cutoff',
#   'a4cdde28c6aa3f2aaf1900606f909e54'): ('propylene glycol production, liquid', 'propylene glycol, liquid'),
#  ('ecoinvent 3.2 cutoff',
#   '690bda9312ab0b5273b48840bfa2e1f5'): ('bark chips production, hardwood, at sawmill', 'bark chips, wet, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   '2f11b8853b0d518d18d41d783d21f4d2'): ('evacuated tube collector production', 'evacuated tube collector'),
#  ('ecoinvent 3.2 cutoff',
#   '7f672683693ad46a9a19aa425ae15413'): ('clinker production', 'sludge, pig iron production'),
#  ('ecoinvent 3.2 cutoff',
#   'dbc742a21de871cfa1b358759c8e3191'): ('lightweight concrete block production, expanded perlite', 'lightweight concrete block, expanded perlite'),
#  ('ecoinvent 3.2 cutoff',
#   'c4f152bcd19354a375c4d3da2564973b'): ('treatment of residue from mechanical treatment, industrial device, municipal waste incineration', 'residue from mechanical treatment, industrial device'),
#  ('ecoinvent 3.2 cutoff',
#   '7fedc548715b554be3961e6334974cad'): ('market for sawlog and veneer log, hardwood, measured as solid wood under bark', 'sawlog and veneer log, hardwood, measured as solid wood under bark'),
#  ('ecoinvent 3.2 cutoff',
#   '646a3aaccf6c2d0e47fb133957d99d98'): ('fibreboard production, soft, from wet & dry processes', 'fibreboard, soft'),
#  ('ecoinvent 3.2 cutoff',
#   'f81ca3cbeb4a84279d7e5757b2e437e4'): ('nuclear fuel factory construction', 'nuclear fuel factory'),
#  ('ecoinvent 3.2 cutoff',
#   'e2a5dae13b9b59d0ece2ce488de958b8'): ('treatment of waste polyvinylchloride, sanitary landfill', 'waste polyvinylchloride'),
#  ('ecoinvent 3.2 cutoff',
#   '68f6d38b038760b6e7dad4e0389f3f36'): ('beam, hardwood, raw, kiln drying to u=20%', 'sawnwood, beam, hardwood, raw, dried (u=20%)'),
#  ('ecoinvent 3.2 cutoff',
#   '12e8f1d61ad36f8d72f09b7d2710c304'): ('metal working, average for copper product manufacturing', 'metal working, average for copper product manufacturing'),
#  ('ecoinvent 3.2 cutoff',
#   '22e2252210c7a51724f58015cdb84bf8'): ('process-specific burdens, hazardous waste incineration plant', 'process-specific burdens, hazardous waste incineration plant'),
#  ('ecoinvent 3.2 cutoff',
#   'f5d267dcd9ceb02476eea934d2f930c5'): ('heat and power co-generation, natural gas, 160kW electrical, lambda=1', 'electricity, low voltage'),
#  ('ecoinvent 3.2 cutoff',
#   '53e597caff6c80ee401aad98b34ee3e5'): ('sulfur dioxide production, liquid', 'sulfur dioxide, liquid'),
#  ('ecoinvent 3.2 cutoff',
#   '4840351149b02294610af606d8eb6588'): ('operation, computer, desktop, with cathode ray tube display, office use', 'operation, computer, desktop, office use'),
#  ('ecoinvent 3.2 cutoff',
#   '3c78fe267258130fc6eb8187823a541e'): ('boric acid production, anhydrous, powder', 'boric acid, anhydrous, powder'),
#  ('ecoinvent 3.2 cutoff',
#   'effe245fdb6a86789ba14e79f8dfd3a6'): ('phenoxy-compound production', 'phenoxy-compound'),
#  ('ecoinvent 3.2 cutoff',
#   '19c751acf4651deb39f4d7247d1df6da'): ('ethanol production from potatoes', "Distiller's Dried Grains with Solubles"),
#  ('ecoinvent 3.2 cutoff',
#   '70b6cb9b6a68623c15fb491c2f0cfc39'): ('acetic acid production, product in 98% solution state', 'acetic acid, without water, in 98% solution state'),
#  ('ecoinvent 3.2 cutoff',
#   'd360e6ff75accb23709d09d6dfa33d58'): ('medium density fibre board production, uncoated', 'medium density fibreboard'),
#  ('ecoinvent 3.2 cutoff',
#   'd9ac2085a8eb5c7120df8e209a0c2eeb'): ('concrete production, for building construction, with cement CEM II/B', 'concrete, high exacting requirements'),
#  ('ecoinvent 3.2 cutoff',
#   '33ef879f2e216fc033a418bebe8a579a'): ('treatment of slaughterhouse waste, rendering', 'slaughterhouse waste'),
#  ('ecoinvent 3.2 cutoff',
#   'de681b1dd01e8b3738e4b2cae671618c'): ('lime mortar production', 'lime mortar'),
#  ('ecoinvent 3.2 cutoff',
#   '9343df7b79ee3866de124a88e8dffe38'): ('ventilation system production, decentralized, 6 x 120 m3/h, polyethylene ducts', 'ventilation system, decentralized, 6 x 120 m3/h, polyethylene ducts'),
#  ('ecoinvent 3.2 cutoff',
#   '6cc83b43ed5e0dc76804a1469a8177ac'): ('decarboxylative cyclization of adipic acid', '2-cyclopentone'),
#  ('ecoinvent 3.2 cutoff',
#   'b940b0a026dd0dce3d6db1adec5cfc73'): ('steel production, chromium steel 18/8, hot rolled', 'steel, chromium steel 18/8, hot rolled'),
#  ('ecoinvent 3.2 cutoff',
#   '86f7be92b2adde7b2253c798990e47a1'): ('iron sulfate production', 'iron sulfate'),
#  ('ecoinvent 3.2 cutoff',
#   '8f1493e04df1845850428191f6795c34'): ('heat and power co-generation, biogas, gas engine', 'heat, central or small-scale, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '39bf605adb7245df78689178934addaa'): ('operation, computer, laptop, active mode', 'operation, computer, laptop, active mode'),
#  ('ecoinvent 3.2 cutoff',
#   '0ce1142973326850b32ec15dee8722cc'): ('planing, beam, hardwood, u=20%', 'shavings, hardwood, loose, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   '40716c313281df51bddb9b4eb88262f6'): ('photovoltaic laminate production, multi-Si wafer', 'photovoltaic laminate, multi-Si wafer'),
#  ('ecoinvent 3.2 cutoff',
#   '8902306a8a3cf3fd88555c15a3ca3c9c'): ('maintenance, train, passenger, regional', 'maintenance, train, passenger, regional'),
#  ('ecoinvent 3.2 cutoff',
#   '9f6f224a96d9168459666039d5eba0e7'): ('planing, lath, hardwood, u=20%', 'shavings, hardwood, loose, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   'd9e220770d1ff363e95c3e3c2f9f2ec8'): ('barley production, organic', 'straw, organic'),
#  ('ecoinvent 3.2 cutoff',
#   '8e6a1bd02ade58182e447bca372f867c'): ('treatment of waste paint, sanitary landfill', 'waste paint'),
#  ('ecoinvent 3.2 cutoff',
#   '3f8f4fd9fd8f5e85f9cd801c70a9569a'): ('planing, board, softwood, u=10%', 'sawnwood, board, softwood, dried (u=10%), planed'),
#  ('ecoinvent 3.2 cutoff',
#   '596cfa5415c2e6a6601ac77e500a62dc'): ('fibreboard production, hard', 'bark chips, wet, measured as dry mass'),
#  ('ecoinvent 3.2 cutoff',
#   'a0e77c76bd5e9c33ee37a8998ac31d5d'): ('rosin size production, for paper production', 'rosin size, for paper production'),
#  ('ecoinvent 3.2 cutoff', '2864ba4a2b96a62923f6718771c76d45'): ('milking',
#   'milking'),
#  ('ecoinvent 3.2 cutoff',
#   'c1ecf3205d33527411ac899175651029'): ('treatment of residue from mechanical treatment, cathode ray tube display, municipal waste incineration', 'residue from mechanical treatment, cathode ray tube display'),
#  ('ecoinvent 3.2 cutoff',
#   '06399c5b121e134b31af475882c7569c'): ('nuclear spent fuel conditioning facility construction', 'nuclear spent fuel conditioning facility'),
#  ('ecoinvent 3.2 cutoff',
#   '16e297840dc9bd8af630907e1bf1c627'): ('operation, printer, laser, colour, per kg printed paper', 'printed paper'),
#  ('ecoinvent 3.2 cutoff',
#   'cd55f50cd67467f7111e4608cf666edd'): ('borax production, anhydrous, powder', 'borax, anhydrous, powder'),
#  ('ecoinvent 3.2 cutoff',
#   '1d5066deecbeb148d4d8c8503e6c4e7f'): ('[sulfonyl]urea-compound production', '[sulfonyl]urea-compound'),
#  ('ecoinvent 3.2 cutoff',
#   '5822bec66f8008c6b6bffaaf96ce417a'): ('extrusion production, plastic pipes', 'extrusion, plastic pipes'),
#  ('ecoinvent 3.2 cutoff',
#   '9030aee499c83484195a02f2e81ab278'): ('hard coal mine operation', 'hard coal'),
#  ('ecoinvent 3.2 cutoff',
#   '13df5f9e6352fafe71e90f9f457549d9'): ('treatment of waste polypropylene, sanitary landfill', 'waste polypropylene'),
#  ('ecoinvent 3.2 cutoff',
#   '3f102950ea746cb432cdc02ef1b2a4eb'): ('electricity production, photovoltaic, 3kWp slanted-roof installation, single-Si, panel, mounted', 'electricity, low voltage'),
#  ('ecoinvent 3.2 cutoff',
#   'b04b5794a75ea207c3da03603a4d676b'): ('prosulfocarb production', 'prosulfocarb'),
#  ('ecoinvent 3.2 cutoff',
#   '6a7a42cf43c1b9a21852ba857fd68974'): ('treatment of scrap copper, municipal incineration', 'scrap copper'),
#  ('ecoinvent 3.2 cutoff',
#   'a5dd8c697f733f73b892e4bee9bf0c54'): ('aluminium drilling, computer numerical controlled', 'aluminium removed by drilling, computer numerical controlled'),
#  ('ecoinvent 3.2 cutoff',
#   'ac34b6ee8fa1095e9983d0d780f54333'): ('treatment of waste polyvinylchloride, municipal incineration', 'waste polyvinylchloride'),
#  ('ecoinvent 3.2 cutoff',
#   'db52de0c6b2bfd9435ce2d2821fe85ed'): ('linerboard production, kraftliner', 'electricity, medium voltage'),
#  ('ecoinvent 3.2 cutoff',
#   'bb61080ebc80c25fc343b2f159561c32'): ('treatment of rainwater mineral oil storage, in wastewater treatment plant, capacity 1.1E10l/year', 'rainwater mineral oil storage'),
#  ('ecoinvent 3.2 cutoff',
#   '427dd50864dbaaf786ece43e6d8d05f7'): ('clinker production', 'waste paint'),
#  ('ecoinvent 3.2 cutoff',
#   '8a23a1c9f18e7f391643a564191ec55b'): ('hydroformylation of butene',
#   '3-methyl-1-butanol'),
#  ('ecoinvent 3.2 cutoff',
#   'f3d538b4549855b61d342b63f62eef57'): ('cement production, pozzolana and fly ash 36-55%, non-US', 'hard coal ash'),
#  ('ecoinvent 3.2 cutoff',
#   '13893379e7249f042a0fbca5c06d7de5'): ('treatment of decarbonising waste, residual material landfill', 'decarbonising waste'),
#  ('ecoinvent 3.2 cutoff',
#   '48651219987e5cba9318bee1f4c8a99b'): ('petroleum and gas production, on-shore', 'natural gas, high pressure'),
#  ('ecoinvent 3.2 cutoff',
#   'b2fac53fe508231919d7abc856e60afb'): ('transport, freight train, diesel, with particle filter', 'transport, freight train'),
#  ('ecoinvent 3.2 cutoff',
#   '292c64b0c90bef4fb92d8064e6dffe5b'): ('soybean meal and crude oil production, mechanical extraction', 'soybean meal'),
#  ('ecoinvent 3.2 cutoff',
#   '92fb6d2b2db61122a95e51bf4dd9e4c2'): ('impact extrusion of steel, hot, 2 strokes', 'impact extrusion of steel, hot, 2 strokes'),
#  ('ecoinvent 3.2 cutoff',
#   '4bf9b5133c4bf1b4969cda81c096b180'): ('aircraft production, medium haul', 'aircraft, medium haul'),
#  ('ecoinvent 3.2 cutoff',
#   'd52d942104f2ed9e035eadd906a9b636'): ('heat and power co-generation, lignite', 'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   'fe51138a5d5e1b488f1799b1454eaef1'): ('laser machining, metal, with CO2-laser, 3200W power', 'laser machining, metal, with CO2-laser, 3200W power'),
#  ('ecoinvent 3.2 cutoff',
#   '6d77a7024f3168908bd979aada2f7f96'): ('tofu production', 'tofu'),
#  ('ecoinvent 3.2 cutoff',
#   '737130002d3bcfa267dd2a89b1f0468d'): ('treatment of blast furnace gas, in power plant',
#   'heat, district or industrial, other than natural gas'),
#  ('ecoinvent 3.2 cutoff',
#   '2e1ead367db589f673afd7def9e53767'): ('treatment of waste paperboard, sorting plant', 'waste paperboard'),
#  ('ecoinvent 3.2 cutoff',
#   '2e0babd1b71cac62c21ffd021faca596'): ('natural gas, burned in gas motor, for storage', 'natural gas, burned in gas motor, for storage'),
#  ('ecoinvent 3.2 cutoff',
#   '70468e9867fd1ddc5df08d5d36ff6985'): ('market for tap water', 'tap water'),
#  ('ecoinvent 3.2 cutoff',
#   'a7364ba503215688c224fafb01f29baf'): ('sodium sulfite production',
#   'sodium sulfite'),
#  ('ecoinvent 3.2 cutoff',
#   '835e5748604735235f7c82e83e3c2597'): ('municipal waste incineration facility construction', 'municipal waste incineration facility'),
#  ('ecoinvent 3.2 cutoff',
#   '4e8c6ab2007d53eef8eefb182dd228b9'): ('treatment of green liquor dregs, residual material landfill', 'green liquor dregs'),
#  ('ecoinvent 3.2 cutoff',
#   '4e3080fb1e477f34e958a6fefe2b3c0b'): ('sanitary landfill facility construction', 'sanitary landfill facility'),
#  ('ecoinvent 3.2 cutoff',
#   'ace4f707a9f88a3534aef3bd88345595'): ('acetone cyanohydrin production', 'acetone cyanohydrin'),
#  ('ecoinvent 3.2 cutoff',
#   '17fd02f413e5e65ca4d2331c2fe2e0c1'): ('steel production, converter, unalloyed', 'steel, unalloyed'),
#  ('ecoinvent 3.2 cutoff',
#   '24b2013ef5b67faa77a955d5c9f3c9d9'): ('market for fluting medium', 'fluting medium'),
#  ('ecoinvent 3.2 cutoff',
#   '9f8f49b39515b158b1e078c623a10029'): ('treatment of waste frit from cathode ray tube production, residual material landfill', 'waste frit from cathode ray tube production'),
#  ('ecoinvent 3.2 cutoff',
#   '1bf6615b2e13463345eac2ffe60ae248'): ('laser machining, metal, with YAG-laser, 40W power', 'laser machining, metal, with YAG-laser, 40W power'),
#  ...}

# %%
row_locations
# Out:
# [((), 'RoW-0'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CSG',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IS',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SGCC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-1'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IS',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-2'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-3'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-4'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN-AH',
#    'CN-FJ',
#    'CN-GD',
#    'CN-HB',
#    'CN-HE',
#    'CN-HN',
#    'CN-HU',
#    'CN-JS',
#    'CN-LN',
#    'CN-SD',
#    'CN-SX',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'IE',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MRO, US only',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-5'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-6'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-7'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SA',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only'),
#   'RoW-8'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-9'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HR',
#    'IE',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'SERC',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-10'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'IE',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-11'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SA',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'WECC, US only'),
#   'RoW-12'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'RU',
#    'SA',
#    'SERC',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-13'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CN',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MT',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'WECC, US only'),
#   'RoW-14'),
#  (('ASCC',
#    'AT',
#    'BA',
#    'CA-AB',
#    'CA-BC',
#    'CA-NT',
#    'CA-YK',
#    'CH',
#    'FR',
#    'HR',
#    'IN',
#    'IT',
#    'JP',
#    'MK',
#    'MRO, US only',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'RFC',
#    'RS',
#    'SERC',
#    'WECC, US only'),
#   'RoW-15'),
#  (('ASCC',
#    'AU',
#    'BA',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NS',
#    'CA-ON',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'ES',
#    'FRCC',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IN',
#    'IT',
#    'KR',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'NPCC, US only',
#    'RFC',
#    'RO',
#    'RS',
#    'SERC',
#    'SI',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'WECC, US only'),
#   'RoW-16'),
#  (('AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HR',
#    'HU',
#    'IE',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW',
#    'UA'),
#   'RoW-17'),
#  (('AT',
#    'AU',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN-AH',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-HA',
#    'CN-HU',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HU',
#    'ID',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'TH',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-18'),
#  (('AT',
#    'AU',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN-AH',
#    'CN-GD',
#    'CN-GS',
#    'CN-HA',
#    'CN-HU',
#    'CN-JS',
#    'CN-JX',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HU',
#    'ID',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'TH',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-19'),
#  (('AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'WECC, US only'),
#   'RoW-20'),
#  (('AT',
#    'AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CN-GD',
#    'CN-GS',
#    'CN-HA',
#    'CN-JS',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SD',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'NPCC, US only',
#    'PT',
#    'RFC',
#    'SERC',
#    'WECC, US only'),
#   'RoW-21'),
#  (('AT', 'BA', 'CZ', 'DE', 'ES', 'FR', 'GR', 'HU', 'MK', 'PL', 'SI', 'SK'),
#   'RoW-22'),
#  (('AT',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-23'),
#  (('AT',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MY',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RS',
#    'RU',
#    'SE',
#    'SI',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-24'),
#  (('AT',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-25'),
#  (('AT',
#    'BE',
#    'BG',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-26'),
#  (('AT',
#    'BE',
#    'CA-AB',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'NL',
#    'SE',
#    'SK',
#    'US'),
#   'RoW-27'),
#  (('AT', 'BE', 'CZ', 'DE', 'ES', 'FR', 'HR', 'IT', 'NL', 'PL', 'PT', 'SK'),
#   'RoW-28'),
#  (('AT', 'BE', 'DE', 'FR', 'IT'), 'RoW-29'),
#  (('AT',
#    'CH',
#    'DE',
#    'HICC',
#    'ID',
#    'IS',
#    'IT',
#    'JP',
#    'MX',
#    'PT',
#    'RU',
#    'TH',
#    'TR',
#    'WECC'),
#   'RoW-30'),
#  (('AT',
#    'CH',
#    'DE',
#    'HICC',
#    'ID',
#    'IS',
#    'IT',
#    'JP',
#    'MX',
#    'PT',
#    'RU',
#    'TH',
#    'TR',
#    'WECC, US only'),
#   'RoW-31'),
#  (('AT', 'CZ', 'DE', 'DK', 'FI', 'KR', 'NL', 'NO', 'PL', 'RU', 'SE', 'SK'),
#   'RoW-32'),
#  (('AU',), 'RoW-33'),
#  (('AU', 'CA', 'TZ', 'US', 'ZA'), 'RoW-34'),
#  (('AU', 'CN', 'ID', 'PL', 'RLA', 'RNA', 'RU', 'WEU', 'ZA'), 'RoW-35'),
#  (('AU', 'RAS', 'RER', 'RLA', 'RNA'), 'RoW-36'),
#  (('BE',), 'RoW-37'),
#  (('BE',
#    'BG',
#    'BR',
#    'CH',
#    'CN-GD',
#    'CN-JS',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HU',
#    'IR',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-38'),
#  (('BG',
#    'CH',
#    'CL',
#    'EE',
#    'HR',
#    'ID',
#    'IN',
#    'LT',
#    'LV',
#    'MX',
#    'MY',
#    'PE',
#    'RU',
#    'TH',
#    'TR',
#    'TW',
#    'TZ',
#    'UA',
#    'ZA'),
#   'RoW-39'),
#  (('BR',), 'RoW-40'),
#  (('BR', 'CA-QC', 'CH', 'CN', 'DE', 'ES', 'FR', 'IN', 'MY', 'PH', 'TN', 'US'),
#   'RoW-41'),
#  (('BR', 'CA-QC', 'US'), 'RoW-42'),
#  (('BR', 'CH'), 'RoW-43'),
#  (('BR', 'CH', 'CN', 'Europe without Switzerland', 'US'), 'RoW-44'),
#  (('BR', 'CO'), 'RoW-45'),
#  (('BR', 'CO', 'IN', 'MY'), 'RoW-46'),
#  (('BR', 'CO', 'MY'), 'RoW-47'),
#  (('BR', 'CO', 'RAF'), 'RoW-48'),
#  (('BR', 'ID', 'MY', 'TH'), 'RoW-49'),
#  (('BR', 'RER', 'US'), 'RoW-50'),
#  (('BR', 'US'), 'RoW-51'),
#  (('CA',), 'RoW-52'),
#  (('CA-AB',), 'RoW-53'),
#  (('CA-AB', 'CA-QC', 'DE', 'DZ', 'NL', 'NO', 'RU'), 'RoW-54'),
#  (('CA-AB', 'DE', 'DZ', 'RU', 'US'), 'RoW-55'),
#  (('CA-AB', 'NG', 'NL', 'US'), 'RoW-56'),
#  (('CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FRCC',
#    'HICC',
#    'IS',
#    'KR',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TZ',
#    'ZA'),
#   'RoW-57'),
#  (('CA-QC',), 'RoW-58'),
#  (('CA-QC', 'CH'), 'RoW-59'),
#  (('CA-QC', 'CH', 'Europe without Switzerland'), 'RoW-60'),
#  (('CA-QC', 'CH', 'Europe without Switzerland', 'US'), 'RoW-61'),
#  (('CA-QC', 'CH', 'FR'), 'RoW-62'),
#  (('CA-QC', 'CN'), 'RoW-63'),
#  (('CA-QC',
#    'CN',
#    'IAI Area 1, Africa',
#    'IAI Area 2, without Quebec',
#    'IAI Area 3, South America',
#    'IAI Area 4&5, without China',
#    'IAI Area 8, Gulf',
#    'IAI Area, EU27 & EFTA',
#    'IAI Area, Europe outside EU & EFTA',
#    'UN-OCEANIA'),
#   'RoW-64'),
#  (('CA-QC', 'DE'), 'RoW-65'),
#  (('CA-QC', 'DE', 'ES', 'FR'), 'RoW-66'),
#  (('CA-QC', 'DE', 'ES', 'FR', 'US'), 'RoW-67'),
#  (('CA-QC', 'DE', 'FR', 'US'), 'RoW-68'),
#  (('CA-QC', 'Europe without Switzerland'), 'RoW-69'),
#  (('CA-QC', 'FR'), 'RoW-70'),
#  (('CA-QC',
#    'IAI Area 2, without Quebec',
#    'IAI Area 3, South America',
#    'IAI Area 4&5, without China',
#    'IAI Area, EU27 & EFTA',
#    'IAI Area, Europe outside EU & EFTA'),
#   'RoW-71'),
#  (('CA-QC', 'PE', 'PG'), 'RoW-72'),
#  (('CA-QC', 'RER'), 'RoW-73'),
#  (('CA-QC', 'US'), 'RoW-74'),
#  (('CA-SK', 'RER'), 'RoW-75'),
#  (('CH',), 'RoW-76'),
#  (('CH', 'CN'), 'RoW-77'),
#  (('CH', 'CN', 'DE', 'FR', 'US'), 'RoW-78'),
#  (('CH', 'CN', 'Europe without Switzerland'), 'RoW-79'),
#  (('CH', 'CN', 'Europe without Switzerland', 'US'), 'RoW-80'),
#  (('CH', 'CN', 'FR', 'US'), 'RoW-81'),
#  (('CH', 'DE', 'NL'), 'RoW-82'),
#  (('CH', 'DE', 'RER w/o CH+DE'), 'RoW-83'),
#  (('CH', 'DE', 'US'), 'RoW-84'),
#  (('CH', 'Europe without Switzerland'), 'RoW-85'),
#  (('CH', 'Europe without Switzerland', 'US'), 'RoW-86'),
#  (('CH', 'SE'), 'RoW-87'),
#  (('CL',), 'RoW-88'),
#  (('CM',), 'RoW-89'),
#  (('CN',), 'RoW-90'),
#  (('CN',
#    'IAI Area 1, Africa',
#    'IAI Area 2, without Quebec',
#    'IAI Area 4&5, without China',
#    'IAI Area, EU27 & EFTA',
#    'IAI Area, Europe outside EU & EFTA',
#    'UN-OCEANIA'),
#   'RoW-91'),
#  (('CN', 'RER'), 'RoW-92'),
#  (('CN', 'RER', 'RNA'), 'RoW-93'),
#  (('CN', 'RU'), 'RoW-94'),
#  (('CN', 'US'), 'RoW-95'),
#  (('CO',), 'RoW-96'),
#  (('CO', 'IN', 'RAF'), 'RoW-97'),
#  (('CO', 'MY'), 'RoW-98'),
#  (('CZ', 'DE', 'GR', 'PL', 'RU', 'SI', 'SK'), 'RoW-99'),
#  (('DE',), 'RoW-100'),
#  (('DE', 'DZ', 'NL', 'NO', 'RU'), 'RoW-101'),
#  (('DE', 'ES', 'FR'), 'RoW-102'),
#  (('DE', 'FR', 'IT'), 'RoW-103'),
#  (('DE', 'GB', 'NL', 'RU'), 'RoW-104'),
#  (('DE', 'NL', 'RER w/o DE+NL+NO', 'RU'), 'RoW-105'),
#  (('DE', 'SE'), 'RoW-106'),
#  (('DE', 'UCTE without Germany'), 'RoW-107'),
#  (('DK',), 'RoW-108'),
#  (('DZ',), 'RoW-109'),
#  (('EE', 'FI', 'IE', 'RU', 'SE'), 'RoW-110'),
#  (('ES',), 'RoW-111'),
#  (('Europe without Switzerland',), 'RoW-112'),
#  (('FR',), 'RoW-113'),
#  (('FR', 'US'), 'RoW-114'),
#  (('GB',), 'RoW-115'),
#  (('GB', 'NL', 'NO'), 'RoW-116'),
#  (('IAI Area, EU27 & EFTA',), 'RoW-117'),
#  (('IL',), 'RoW-118'),
#  (('IN',), 'RoW-119'),
#  (('JP', 'RER'), 'RoW-120'),
#  (('MA',), 'RoW-121'),
#  (('MA', 'US'), 'RoW-122'),
#  (('MY',), 'RoW-123'),
#  (('NL',), 'RoW-124'),
#  (('NO',), 'RoW-125'),
#  (('NORDEL',), 'RoW-126'),
#  (('PH',), 'RoW-127'),
#  (('PT',), 'RoW-128'),
#  (('RAF', 'RME', 'RU'), 'RoW-129'),
#  (('RER',), 'RoW-130'),
#  (('RNA',), 'RoW-131'),
#  (('SE',), 'RoW-132'),
#  (('SK',), 'RoW-133'),
#  (('TH',), 'RoW-134'),
#  (('TR',), 'RoW-135'),
#  (('UCTE',), 'RoW-136'),
#  (('US',), 'RoW-137'),
#  (('WEU',), 'RoW-138'),
#  (('ZA',), 'RoW-139')]

# %%
locations
# Out:
# {('ethylene hydration',
#   'diethyl ether, without water, in 99.95% solution state'): ('RER',),
#  ('treatment of waste paperboard, municipal incineration',
#   'heat, for reuse in municipal waste incineration only'): (),
#  ('clinker production', 'waste plastic, mixture'): ('CH',
#   'Europe without Switzerland',
#   'US'),
#  ('glyphosate production', 'glyphosate'): ('RER',),
#  ('steam production in chemical industry',
#   'heat, in chemical industry'): ('RER',),
#  ('diammonium phosphate production', 'nitrogen fertiliser, as N'): ('RER',),
#  ('swath, by rotary windrower', 'swath, by rotary windrower'): ('CA-QC', 'CH'),
#  ('treatment of wastewater from hard fibreboard production, capacity 5E9l/year',
#   'wastewater from hard fibreboard production'): ('RER',),
#  ('laser machining, metal, with YAG-laser, 30W power',
#   'laser machining, metal, with YAG-laser, 30W power'): ('CA-QC', 'RER'),
#  ('methylene diphenyl diisocyanate production',
#   'methylene diphenyl diisocyanate'): ('RER',),
#  ('operation, computer, laptop, standby/sleep mode',
#   'operation, computer, laptop, standby/sleep mode'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland'),
#  ('air separation facility construction', 'air separation facility'): ('RER',),
#  ('primary zinc production from concentrate', 'copper cake'): ('CA-QC',),
#  ('brass turning, primarily dressing, conventional',
#   'brass removed by turning, primarily dressing, conventional'): ('RER',),
#  ('bromine production', 'bromine'): ('RER',),
#  ('laser machining, metal, with YAG-laser, 200W power',
#   'laser machining, metal, with YAG-laser, 200W power'): ('CA-QC', 'RER'),
#  ('xylene production', 'xylene'): ('RER',),
#  ('transport, passenger car, small size, petrol, EURO 4',
#   'transport, passenger car, small size, petrol, EURO 4'): ('RER',),
#  ('treatment of used air filter, central unit, 600 m3/h',
#   'used air filter central unit, 600 m3/h'): ('CH',),
#  ('cumene production', 'cumene'): ('RER',),
#  ('blast furnace production', 'blast furnace'): ('RER',),
#  ('clinker production', 'sewage sludge, dried'): ('CH',
#   'Europe without Switzerland',
#   'US'),
#  ('nuclear fuel element production, for pressure water reactor, UO2 3.9% & MOX',
#   'nuclear fuel element, for pressure water reactor, UO2 3.9% & MOX'): ('UCTE',),
#  ('transport, passenger, motor scooter',
#   'transport, passenger, motor scooter'): ('CH',),
#  ('treatment of scrap steel, inert material landfill', 'scrap steel'): ('CH',),
#  ('impact extrusion of steel, hot, deformation stroke',
#   'impact extrusion of steel, hot, deformation stroke'): ('RER',),
#  ('furnace production, wood chips, hardwood storage area, 1000kW',
#   'furnace, wood chips, hardwood storage area, 1000kW'): ('CH',),
#  ('gas boiler production', 'gas boiler'): ('RER',),
#  ('heat production, wood chips from industry, at furnace 1000kW',
#   'heat, district or industrial, other than natural gas'): ('CH',),
#  ('laser machining, metal, with CO2-laser, 2000W power',
#   'laser machining, metal, with CO2-laser, 2000W power'): ('CA-QC', 'RER'),
#  ('treatment of waste building wood, chrome preserved, municipal incineration',
#   'waste building wood, chrome preserved'): ('CH',),
#  ('building machine production', 'building machine'): ('RER',),
#  ('contouring, bronze', 'contouring, bronze'): ('CA-QC', 'RER'),
#  ('solid manure loading and spreading, by hydraulic loader and spreader',
#   'solid manure loading and spreading, by hydraulic loader and spreader'): ('CA-QC',
#   'CH'),
#  ('aluminium milling, small parts',
#   'aluminium removed by milling, small parts'): ('RER',),
#  ('portafer production', 'portafer'): ('CA-QC', 'RER'),
#  ('section bar extrusion, aluminium',
#   'section bar extrusion, aluminium'): ('RER',),
#  ('treatment of used desktop computer, manual dismantling',
#   'used desktop computer'): ('CH',),
#  ('treatment of raw sewage sludge, municipal incineration',
#   'heat, for reuse in municipal waste incineration only'): (),
#  ('hydroquinone production', 'hydroquinone'): ('RER',),
#  ('methyl ethyl ketone production', 'methyl ethyl ketone'): ('RER',),
#  ('furnace production, wood chips, average storage area, 300kW',
#   'furnace, wood chips, average storage area, 300kW'): ('CH',),
#  ('paper production, newsprint, virgin', 'paper, newsprint'): ('CA-QC', 'RER'),
#  ('nuclear fuel element production, for boiling water reactor, UO2 4.0% & MOX',
#   'nuclear fuel element, for boiling water reactor, UO2 4.0% & MOX'): ('DE',
#   'UCTE without Germany'),
#  ('rape seed production, for sowing', 'rape seed, for sowing'): ('CH',),
#  ('ethoxylated alcohol (AE7) production, palm kernel oil',
#   'ethoxylated alcohol (AE7)'): ('RER',),
#  ('heat production, untreated waste wood, at furnace 1000-5000 kW, state-of-the-art 2014',
#   'heat, district or industrial, other than natural gas'): ('CH',),
#  ('treatment of conditioned spent nuclear fuel, in interim storage',
#   'conditioned spent nuclear fuel'): ('CH',),
#  ('market for cement, alternative constituents 6-20%',
#   'cement, alternative constituents 6-20%'): ('CH',
#   'Europe without Switzerland'),
#  ('4-methyl-2-pentanone production', '4-methyl-2-pentanone'): ('RER',),
#  ('heat production, wood chips from industry, at furnace 300kW, state-of-the-art 2014',
#   'heat, district or industrial, other than natural gas'): ('CH',),
#  ('pyridazine-compound production', 'pyridazine-compound'): ('RER',),
#  ('heat production, light fuel oil, at boiler 10kW condensing, non-modulating',
#   'heat, central or small-scale, other than natural gas'): ('CH',
#   'Europe without Switzerland'),
#  ('treatment of coating from waste cathode ray tube display, municipal waste incineration',
#   'coating from waste cathode ray tube display'): ('CH',),
#  ('treatment of redmud from bauxite digestion, residual material landfill',
#   'redmud from bauxite digestion'): ('CH',),
#  ('sodium amide production', 'sodium amide'): ('RER',),
#  ('photovoltaic module production, building-integrated, for slanted-roof installation',
#   'photovoltaic module, building-integrated, for slanted-roof installation'): ('RER',),
#  ('green manure growing, Swiss integrated production, until April',
#   'green manure, Swiss integrated production, until April'): ('CH',),
#  ('unreinforced concrete production, with cement CEM II/B',
#   'concrete, normal'): ('CH',),
#  ('softwood forestry, paraná pine, sustainable forest management',
#   'roundwood, paraná pine from sustainable forest management, under bark'): ('BR',),
#  ('planing, board, hardwood, u=10%',
#   'shavings, hardwood, loose, measured as dry mass'): ('CA-QC', 'CH'),
#  ('plywood production, for outdoor use', 'plywood, for outdoor use'): ('CA-QC',
#   'RER'),
#  ('iron (III) chloride production, product in 40% solution state',
#   'iron (III) chloride, without water, in 40% solution state'): ('CH',),
#  ('concrete production 30-32MPa, RNA only', 'concrete, 30-32MPa'): ('CA-QC',),
#  ('hydropower plant construction, reservoir, alpine region',
#   'hydropower plant, reservoir, alpine region'): ('RER',),
#  ('wastewater treatment facility construction, capacity 4.7E10l/year',
#   'wastewater treatment facility, capacity 4.7E10l/year'): ('CH',),
#  ('aluminium turning, primarily roughing, computer numerical controlled',
#   'aluminium removed by turning, primarily roughing, computer numerical controlled'): ('RER',),
#  ('treatment of waste sealing sheet, polyvinylchloride, municipal incineration',
#   'waste sealing sheet, polyvinylchloride'): ('CH',),
#  ('isoproturon production', 'isoproturon'): ('RER',),
#  ('treatment of waste graphical paper, municipal incineration',
#   'waste graphical paper'): ('CH',),
#  ('barley grain, feed production, organic',
#   'barley grain, feed, organic'): ('CH',),
#  ('treatment of used door, outer, wood-aluminium, collection for final disposal',
#   'used door, outer, wood-aluminium'): ('CH',),
#  ('tap water production, microstrainer treatment', 'tap water'): ('CA-QC',
#   'Europe without Switzerland'),
#  ('tillage, rotary cultivator', 'tillage, rotary cultivator'): ('CA-QC', 'CH'),
#  ('prosulfocarb production', 'prosulfocarb'): ('RER',),
#  ('tofu production', 'tofu'): ('CA-QC',),
#  ('treatment of copper in car shredder residue, municipal incineration',
#   'copper in car shredder residue'): ('CH',),
#  ('beam, softwood, raw, kiln drying to u=10%',
#   'sawnwood, beam, softwood, raw, dried (u=10%)'): ('CA-QC', 'CH'),
#  ('uranium production, enriched 4.2%, centrifugal enrichment',
#   'enriched uranium, 4.2%'): ('CH',),
#  ('cement production, Portland', 'cement, Portland'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland',
#   'US'),
#  ('market for waste sealing sheet, polyvinylchloride',
#   'waste sealing sheet, polyvinylchloride'): ('CH',),
#  ('treatment of recovered paper to linerboard, testliner',
#   'heat, district or industrial, other than natural gas'): ('RER',),
#  ('aluminium milling, average',
#   'aluminium removed by milling, average'): ('RER',),
#  ('market for lean concrete', 'lean concrete'): ('CH',),
#  ('catch crop growing, ryegrass-Egyptian&Persian clover-mixture, August-October, organic fertiliser 30 kg N, one cut',
#   'ryegrass-Egyptian&Persian clover-mixture silage'): ('CH',),
#  ('treatment of biogas, purification to methane 96 vol-%',
#   'methane, 96% by volume'): ('CH',),
#  ('lath, hardwood, raw, kiln drying to u=20%',
#   'sawnwood, lath, hardwood, raw, dried (u=20%)'): ('CA-QC', 'CH'),
#  ('steel milling, large parts',
#   'steel removed by milling, large parts'): ('RER',),
#  ('anode refinery construction', 'anode refinery'): ('SE',),
#  ('ventilation of dwellings, central, 1 x 720 m3/h, steel ducts, with earth tube heat exchanger',
#   'ventilation of dwellings, central, 1 x 720 m3/h'): ('CH',),
#  ('electricity production, wind, <1MW turbine, onshore',
#   'electricity, high voltage'): ('ASCC',
#   'AT',
#   'AU',
#   'BE',
#   'BG',
#   'BR',
#   'CA-AB',
#   'CA-BC',
#   'CA-MB',
#   'CA-NB',
#   'CA-NF',
#   'CA-NS',
#   'CA-NT',
#   'CA-ON',
#   'CA-PE',
#   'CA-SK',
#   'CA-YK',
#   'CH',
#   'CL',
#   'CN-AH',
#   'CN-BJ',
#   'CN-CQ',
#   'CN-FJ',
#   'CN-GD',
#   'CN-GS',
#   'CN-GX',
#   'CN-GZ',
#   'CN-HA',
#   'CN-HB',
#   'CN-HE',
#   'CN-HL',
#   'CN-HN',
#   'CN-HU',
#   'CN-JL',
#   'CN-JS',
#   'CN-JX',
#   'CN-LN',
#   'CN-NM',
#   'CN-NX',
#   'CN-QH',
#   'CN-SA',
#   'CN-SC',
#   'CN-SD',
#   'CN-SH',
#   'CN-SX',
#   'CN-TJ',
#   'CN-XJ',
#   'CN-YN',
#   'CN-ZJ',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'EE',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'GR',
#   'HICC',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IN',
#   'IR',
#   'IT',
#   'JP',
#   'KR',
#   'LT',
#   'LU',
#   'LV',
#   'MRO, US only',
#   'MX',
#   'NL',
#   'NO',
#   'NPCC, US only',
#   'PE',
#   'PL',
#   'PT',
#   'RFC',
#   'RO',
#   'RU',
#   'SE',
#   'SERC',
#   'SK',
#   'SPP',
#   'TR',
#   'TRE',
#   'TW',
#   'UA',
#   'WECC, US only',
#   'ZA'),
#  ('uranium enrichment diffusion facility construction',
#   'uranium enrichment diffusion facility'): ('US',),
#  ('treatment of waste polyethylene terephtalate, municipal incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('delimbing, with excavator-based processor',
#   'delimbing/sorting, excavator-based processor'): ('RER',),
#  ('treatment of residue from mechanical treatment, laptop computer, municipal waste incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('start-up, heat and power co-generation unit, 160kW electrical',
#   'start-up, heat and power co-generation unit, 160kW electrical'): ('RER',),
#  ('nuclear waste storage construction, interim, for high level radioactive waste before final repository',
#   'nuclear waste storage, interim, for high level radioactive waste before final repository'): ('CH',),
#  ('glued laminated timber production, for indoor use',
#   'residual wood, dry'): ('CA-QC', 'RER'),
#  ('photovoltaic cell production, single-Si wafer',
#   'photovoltaic cell, single-Si wafer'): ('RER',),
#  ('packaging glass production, brown', 'packaging glass, brown'): ('CH',
#   'DE',
#   'RER w/o CH+DE'),
#  ('chromium oxide production, flakes', 'chromium oxide, flakes'): ('RER',),
#  ('maintenance, stirling heat and power co-generation unit, 3kW electrical, wood pellet, future',
#   'maintenance, stirling heat and power co-generation unit, 3kW electrical, wood pellet, future'): ('CH',),
#  ('heat and power co-generation, lignite', 'electricity, high voltage'): ('CZ',
#   'DE',
#   'GR',
#   'PL',
#   'RU',
#   'SI',
#   'SK'),
#  ('magnesium factory construction', 'magnesium factory'): ('RER',),
#  ('phosphoric acid production, dihydrate process',
#   'phosphoric acid, fertiliser grade, without water, in 70% solution state'): ('MA',
#   'US'),
#  ('nuclear fuel factory construction', 'nuclear fuel factory'): ('CN', 'US'),
#  ('heat and power co-generation unit construction, 500kW electrical, components for heat only',
#   'heat and power co-generation unit, 500kW electrical, components for heat only'): ('RER',),
#  ('dimethyl sulfoxide production', 'dimethyl sulfoxide'): ('RER',),
#  ('treatment of used electric bicycle', 'used electric bicycle'): ('CH',),
#  ('market for paper, woodcontaining, lightweight coated',
#   'paper, woodcontaining, lightweight coated'): ('RER',),
#  ('power saw production, with catalytic converter',
#   'power saw, with catalytic converter'): ('RER',),
#  ('forwarding, forwarder', 'forwarding, forwarder'): ('RER',),
#  ('drying, sewage sludge', 'raw sewage sludge'): ('CH',),
#  ('chloropropionic acid production', 'chloropropionic acid'): ('RER',),
#  ('electricity production, hydro, reservoir, alpine region',
#   'electricity, high voltage'): ('ASCC',
#   'AT',
#   'BA',
#   'CA-AB',
#   'CA-BC',
#   'CA-NT',
#   'CA-YK',
#   'CH',
#   'FR',
#   'HR',
#   'IN',
#   'IT',
#   'JP',
#   'MK',
#   'MRO, US only',
#   'NO',
#   'NPCC, US only',
#   'PE',
#   'RFC',
#   'RS',
#   'SERC',
#   'WECC, US only'),
#  ('deep drawing, steel, 3500 kN press, automode',
#   'deep drawing, steel, 3500 kN press, automode'): ('RER',),
#  ('nuclear power plant construction, pressure water reactor 650MW',
#   'nuclear power plant, pressure water reactor, 650MW'): ('CA-QC',),
#  ('solder factory construction', 'solder factory'): ('RER',),
#  ('concrete production, for civil engineering, with cement CEM II/A',
#   'concrete, sole plate and foundation'): ('CH',),
#  ('sawing, softwood', 'sawnwood, softwood, raw'): ('CA-QC', 'CH'),
#  ('sodium tripolyphosphate production', 'sodium tripolyphosphate'): ('RER',),
#  ('petroleum refinery operation', 'pitch'): ('CH',
#   'Europe without Switzerland'),
#  ('assembly of generator and motor, auxilliaries and energy use, heat and power co-generation unit, 160kW electrical',
#   'assembly of generator and motor, auxilliaries and energy use, for heat and power co-generation unit, 160 KW electrical'): ('RER',),
#  ('air separation, xenon krypton purification', 'xenon, gaseous'): ('CA-QC',
#   'RER'),
#  ('laminating service, foil, with acrylic binder',
#   'laminating service, foil, with acrylic binder'): ('CA-QC', 'RER'),
#  ('maize grain production, organic', 'maize grain, organic'): ('CH',),
#  ('treatment of recovered paper to linerboard, testliner',
#   'linerboard'): ('CA-QC', 'RER'),
#  ('treatment of waste fibreboard, collection for final disposal',
#   'waste fibreboard'): ('CH',),
#  ('treatment of used window frame, wood, collection for final disposal',
#   'used window frame, wood'): ('CH',),
#  ('electricity production, coal, aluminium industry',
#   'electricity, high voltage, aluminium industry'): ('CN',
#   'IAI Area 1, Africa',
#   'IAI Area 2, without Quebec',
#   'IAI Area 4&5, without China',
#   'IAI Area, EU27 & EFTA',
#   'IAI Area, Europe outside EU & EFTA',
#   'UN-OCEANIA'),
#  ('ethanol, from fermentation, to niche market for ethanol, at service station',
#   'ethanol, without water, in 99.7% solution state, from fermentation, at service station'): ('CH',),
#  ('planning, cogen unit mini CHP plant',
#   'planning, cogen unit mini CHP plant'): ('CH',),
#  ('water storage construction', 'water storage'): ('CH',),
#  ('gas motor production, 206kW', 'gas motor, 206kW'): ('RER',),
#  ('ethylene dichloride production', 'ethylene dichloride'): ('RER',),
#  ('energy saving, from ventilation system, 6 x 120 m3/h, polyethylene ducts, with earth tube heat exchanger',
#   'energy saving'): ('CH',),
#  ('tube insulation production, elastomere',
#   'tube insulation, elastomere'): ('DE',),
#  ('sawing and planing, paraná pine, kiln dried',
#   'wood chips, dry, measured as dry mass'): ('BR',),
#  ('alfalfa/grass silage production', 'alfalfa-grass silage'): ('CA-QC',),
#  ('heat and power co-generation, natural gas, 160kW electrical, Jakobsberg',
#   'heat, central or small-scale, natural gas, Jakobsberg'): ('CH',),
#  ('treatment of lignite ash, sanitary landfill', 'lignite ash'): ('CH',),
#  ('bale loading', 'bale loading'): ('CA-QC', 'CH'),
#  ('ammonia production, steam reforming, liquid', 'ammonia, liquid'): ('RER',),
#  ('tert-butyl amine production', 'tert-butyl amine'): ('RER',),
#  ('fibreboard production, hard', 'residual wood, dry'): ('RER',),
#  ('stone groundwood pulp production', 'stone groundwood pulp'): ('RER',),
#  ('refractory production, basic, packed',
#   'refractory, basic, packed'): ('DE',),
#  ('petroleum refinery operation', 'petrol, unleaded'): ('CH',
#   'Europe without Switzerland'),
#  ('market for tap water', 'tap water'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland'),
#  ('heat production, untreated waste wood, at furnace 1000-5000 kW',
#   'waste wood, untreated'): ('CH',),
#  ('treatment of spent sawing slurry from Si-wafer cutting',
#   'spent sawing slurry from Si-wafer cutting'): ('RER',),
#  ('treatment of waste emulsion paint, hazardous waste incineration',
#   'waste emulsion paint'): ('CH',),
#  ('glued laminated timber production, for indoor use',
#   'glued laminated timber, for indoor use'): ('CA-QC', 'RER'),
#  ('silicon production, metallurgical grade',
#   'silicon, metallurgical grade'): ('NO',),
#  ('blow moulding production', 'blow moulding'): ('CA-QC', 'RER'),
#  ('silver-gold mine operation with refinery', 'silver'): ('CL',),
#  ('heat and power co-generation unit construction, organic Rankine cycle, 1400kW thermal, components for electricity only',
#   'heat and power co-generation unit, organic Rankine cycle, 1400kW thermal, components for electricity only'): ('CH',),
#  ('window frame production, wood, U=1.5 W/m2K',
#   'wood pellet, measured as dry mass'): ('CA-QC', 'RER'),
#  ('foam glass factory construction', 'foam glass factory'): ('BE',),
#  ('market for diesel', 'diesel'): ('CH', 'Europe without Switzerland'),
#  ('welding, arc, aluminium', 'welding, arc, aluminium'): ('CA-QC', 'RER'),
#  ('heat production, natural gas, at boiler condensing modulating <100kW',
#   'heat, central or small-scale, natural gas'): ('CH',
#   'Europe without Switzerland'),
#  ('treatment of wastewater from wafer fabrication, capacity 1.1E10l/year',
#   'wastewater from wafer fabrication'): ('CH',),
#  ('planing, beam, softwood, u=20%',
#   'shavings, softwood, loose, measured as dry mass'): ('CA-QC', 'CH'),
#  ('wastewater treatment facility construction, capacity 1.1E10l/year',
#   'wastewater treatment facility, capacity 1.1E10l/year'): ('CH',),
#  ('market for irrigation', 'irrigation'): ('BR',
#   'CA-QC',
#   'CH',
#   'CN',
#   'DE',
#   'ES',
#   'FR',
#   'IN',
#   'MY',
#   'PH',
#   'TN',
#   'US'),
#  ('pentaerythritol production in sodium hydroxide solution',
#   'sodium formate'): ('RER',),
#  ('insulation spiral-seam duct production, rockwool, DN 400, 30 mm',
#   'insulation spiral-seam duct, rockwool, DN 400, 30 mm'): ('RER',),
#  ('ammonium nitrate production', 'ammonium nitrate, as N'): ('RER',),
#  ('miscanthus rhizome production, for planting',
#   'miscanthus rhizome, for planting'): ('DE',),
#  ('cast iron drilling, computer numerical controlled',
#   'cast iron removed by drilling, computer numerical controlled'): ('RER',),
#  ('cement production, blast furnace slag 18-30% and 18-30% other alternative constituents',
#   'cement, blast furnace slag 18-30% and 18-30% other alternative constituents'): ('CH',
#   'Europe without Switzerland'),
#  ('wastewater treatment facility construction, capacity 1.6E8l/year',
#   'wastewater treatment facility, capacity 1.6E8l/year'): ('CH',),
#  ('treatment of precious metal from electronics scrap, in anode slime, precious metal extraction',
#   'gold'): ('SE',),
#  ('nuclear waste storage construction, interim, for low level radioactive waste before final repository',
#   'nuclear waste storage, interim, for low level radioactive waste before final repository'): ('CH',),
#  ('transport, freight, lorry 16-32 metric ton, EURO3',
#   'transport, freight, lorry 16-32 metric ton, EURO3'): ('RER',),
#  ('maize seed production, organic, for sowing',
#   'maize seed, organic, for sowing'): ('CH',),
#  ('industrial furnace production, natural gas',
#   'industrial furnace, natural gas'): ('RER',),
#  ('trichloroacetic acid production', 'trichloroacetic acid'): ('RER',),
#  ('sawing, softwood', 'bark'): ('CA-QC', 'CH'),
#  ('heat production, natural gas, at boiler atmospheric low-NOx non-modulating <100kW',
#   'heat, central or small-scale, natural gas'): ('Europe without Switzerland',),
#  ('fluting medium production, semichemical',
#   'electricity, medium voltage'): ('RER',),
#  ('unknown land use, on arable land recently transformed from shrubland',
#   'unknown land use'): ('BR', 'CO'),
#  ('jute production, irrigated', 'jute fibre'): ('IN',),
#  ('heat and power co-generation unit construction, 500kW electrical, components for electricity only',
#   'heat and power co-generation unit, 500kW electrical, components for electricity only'): ('RER',),
#  ('treatment of used vegetable cooking oil, purification',
#   'used vegetable cooking oil, purified'): ('CA-QC', 'CH', 'FR'),
#  ('treatment of dust, alloyed electric arc furnace steel, residual material landfill',
#   'dust, alloyed electric arc furnace steel'): ('CH',),
#  ('green manure growing, Swiss integrated production, until March',
#   'green manure, Swiss integrated production, until March'): ('CH',),
#  ('beam, hardwood, raw, kiln drying to u=20%',
#   'sawnwood, beam, hardwood, raw, dried (u=20%)'): ('CA-QC', 'CH'),
#  ('treatment of waste polyethylene terephtalate, sanitary landfill',
#   'waste polyethylene terephtalate'): ('CH',),
#  ('motor scooter production', 'motor scooter, 50 cubic cm engine'): ('RER',),
#  ('hardwood forestry, beech, sustainable forest management',
#   'sawlog and veneer log, hardwood, measured as solid wood under bark'): ('DE',),
#  ('tube insulation factory construction', 'tube insulation factory'): ('DE',),
#  ('polymethyl methacrylate production, sheet',
#   'polymethyl methacrylate, sheet'): ('RER',),
#  ('phosphorus pentachloride production', 'phosphorus pentachloride'): ('CN',),
#  ('treatment of waste, from silicon wafer production, underground deposit',
#   'waste, from silicon wafer production'): ('DE',),
#  ('treatment of residue from mechanical treatment, industrial device, municipal waste incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('linerboard production, kraftliner', 'residual softwood, wet'): ('CA-QC',
#   'RER'),
#  ('petroleum and gas production, off-shore', 'petroleum'): ('GB', 'NL', 'NO'),
#  ('market for electricity, high voltage',
#   'electricity, high voltage'): ('ASCC', 'AT', 'AU', 'BA', 'BE', 'BG', 'BR', 'CA-AB', 'CA-BC', 'CA-MB', 'CA-NB', 'CA-NF', 'CA-NS', 'CA-NT', 'CA-NU', 'CA-ON', 'CA-PE', 'CA-QC', 'CA-SK', 'CA-YK', 'CH', 'CL', 'CSG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'FRCC', 'GB', 'GR', 'HICC', 'HR', 'HU', 'ID', 'IE', 'IN', 'IR', 'IS', 'IT', 'JP', 'KR', 'LT', 'LU', 'LV', 'MK', 'MRO, US only', 'MT', 'MX', 'MY', 'NL', 'NO', 'NPCC, US only', 'PE', 'PL', 'PT', 'RFC', 'RO', 'RS', 'RU', 'SA', 'SE', 'SERC', 'SGCC', 'SI', 'SK', 'SPP', 'TH', 'TR', 'TRE', 'TW', 'TZ', 'UA', 'WECC, US only', 'ZA'),
#  ('market for sawlog and veneer log, softwood, debarked, measured as solid wood',
#   'sawlog and veneer log, softwood, debarked, measured as solid wood'): ('RER',),
#  ('fibreboard production, soft, from wet & dry processes',
#   'fibreboard, soft'): ('CA-QC', 'Europe without Switzerland'),
#  ('transport, passenger car, medium size, petrol, EURO 5',
#   'transport, passenger car, medium size, petrol, EURO 5'): ('RER',),
#  ('treatment of waste polystyrene, municipal incineration',
#   'heat, for reuse in municipal waste incineration only'): (),
#  ('photovoltaic facade installation, 3kWp, single-Si, laminated, integrated, at building',
#   'photovoltaic facade installation, 3kWp, single-Si, laminated, integrated, at building'): ('CH',),
#  ('chromium steel drilling, computer numerical controlled',
#   'chromium steel removed by drilling, computer numerical controlled'): ('RER',),
#  ('gold-silver-zinc-lead-copper mine operation and refining',
#   'copper'): ('SE',),
#  ('maintenance, goods wagon', 'maintenance, goods wagon'): ('RER',),
#  ('sodium chloride production, powder', 'sodium chloride, powder'): ('RER',),
#  ('roof tile production', 'roof tile'): ('RER',),
#  ('calcium borates production', 'calcium borates'): ('TR',),
#  ('transport, freight, lorry 3.5-7.5 metric ton, EURO5',
#   'transport, freight, lorry 3.5-7.5 metric ton, EURO5'): ('RER',),
#  ('rock crushing', 'rock crushing'): ('RER',),
#  ('glass wool mat production', 'glass wool mat'): ('CA-QC', 'CH'),
#  ('barley seed production, organic, for sowing',
#   'barley seed, organic, for sowing'): ('CH',),
#  ('treatment of waste aluminium, sanitary landfill',
#   'waste aluminium'): ('CH',),
#  ('polyester resin production, unsaturated',
#   'polyester resin, unsaturated'): ('RER',),
#  ('operation, computer, desktop, with liquid crystal display, active mode',
#   'operation, computer, desktop, with liquid crystal display, active mode'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland'),
#  ('market for electricity, for reuse in municipal waste incineration only',
#   'electricity, for reuse in municipal waste incineration only'): ('AT',
#   'BE',
#   'BG',
#   'CH',
#   'CZ',
#   'DE',
#   'DK',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'HU',
#   'IT',
#   'JP',
#   'KR',
#   'LU',
#   'NL',
#   'NO',
#   'PL',
#   'PT',
#   'RU',
#   'SE',
#   'SK',
#   'TR',
#   'TW'),
#  ('treatment of waste cement-fibre slab, municipal incineration',
#   'waste cement-fibre slab, dismantled'): ('CH',),
#  ('yarding and processing, mobile cable yarder on truck',
#   'cable yarding'): ('RER',),
#  ('silicon production, single crystal, Czochralski process, electronics',
#   'silicon, single crystal, Czochralski process, electronics'): ('RER',),
#  ('molecular sieve separation of naphtha', 'heptane'): ('RER',),
#  ('blast oxygen furnace converter production',
#   'blast oxygen furnace converter'): ('RER',),
#  ('dolomite production', 'dolomite'): ('RER',),
#  ('treatment of used blower and heat exchange unit, KWL 250',
#   'used blower and heat exchange unit KWL 250'): ('CH',),
#  ('market for diesel, low-sulfur', 'diesel, low-sulfur'): ('CH',
#   'Europe without Switzerland'),
#  ('hazardous waste incineration facility construction',
#   'hazardous waste incineration facility'): ('CH',),
#  ('alkylbenzene production, linear', 'alkylbenzene, linear'): ('CA-QC', 'RER'),
#  ('magnesium production, electrolysis', 'magnesium'): ('IL',),
#  ('wood preservation, vacuum pressure method, organic salt, Cr-free, outdoor use, ground contact',
#   'wood preservation, vacuum pressure method, organic salts, Cr-free, outdoor use, ground contact'): ('RER',),
#  ('train production, passenger, high speed',
#   'train, passenger, high speed'): ('DE',),
#  ('triazine-compound production, unspecified',
#   'triazine-compound, unspecified'): ('RER',),
#  ('wood preservation, dipping/immersion, water-based preservative, outdoor use, no ground contact',
#   'wood preservation, dipping/immersion method, water-based, outdoor use, no ground contact'): ('RER',),
#  ('plywood production, for indoor use',
#   'wood chips, dry, measured as dry mass'): ('RER',),
#  ('vermiculite mine operation', 'vermiculite'): ('ZA',),
#  ('textile production, jute', 'textile, jute'): ('IN',),
#  ('nylon 6 production', 'nylon 6'): ('RER',),
#  ('treatment of automobile catalyst', 'platinum'): ('RER',),
#  ('layered sodium silicate production, SKS-6, powder',
#   'layered sodium silicate, SKS-6, powder'): ('RER',),
#  ('vinyl fluoride production', 'hydrogen fluoride'): ('US',),
#  ('market for heat, in chemical industry',
#   'heat, in chemical industry'): ('RER',),
#  ('wood preservation, dipping/immersion, water-based preservative, indoor use, occasionally wet',
#   'wood preservation, dipping/immersion method, water-based, indoor use, occasionally wet'): ('RER',),
#  ('isophthalic acid based unsaturated polyester resin production',
#   'isophthalic acid based unsaturated polyester resin'): ('RER',),
#  ('adipic acid production', 'adipic acid'): ('RER',),
#  ('treatment of waste bitumen sheet, municipal incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('operation, computer, laptop, 68% active work with internet access 0.2 Mbit/s',
#   'operation, computer, laptop, 68% active work with internet access 0.2 Mbit/s'): ('CA-QC',
#   'CH'),
#  ('market for transport, passenger car, EURO 5',
#   'transport, passenger car, EURO 5'): ('RER',),
#  ('sodium chloride electrolysis', 'sodium'): ('RER',),
#  ('green manure growing, organic, until April',
#   'green manure, organic, until April'): ('CH',),
#  ('lime production, milled, packed', 'lime, packed'): ('CH',),
#  ('chlor-alkali electrolysis, membrane cell', 'hydrogen, liquid'): ('CA-QC',
#   'RER'),
#  ('tellurium production, semiconductor-grade',
#   'tellurium, semiconductor-grade'): ('CA-QC',),
#  ('treatment of dross from Al electrolysis, residual material landfill',
#   'dross from Al electrolysis'): ('CH',),
#  ('n-olefins production', 'n-olefins'): ('RER',),
#  ('expanded vermiculite production', 'expanded vermiculite'): ('CH',),
#  ('uranium production, centrifuge, enriched 4.0%',
#   'uranium, enriched 4.0%, per separative work unit'): ('DE',
#   'GB',
#   'NL',
#   'RU'),
#  ('treatment of wastewater from anaerobic digestion of whey, capacity 1E9l/year',
#   'wastewater from anaerobic digestion of whey'): ('CH',),
#  ('polyurethane production, flexible foam',
#   'polyurethane, flexible foam'): ('RER',),
#  ('treatment of wastewater from liquid crystal display backlight production, capacity 1.1E10l/year',
#   'wastewater from liquid crystal display backlight production'): ('CH',),
#  ('ethylene production, average', 'ethylene, average'): ('RER',),
#  ('milking', 'milking'): ('CH',),
#  ('urea ammonium nitrate production', 'nitrogen fertiliser, as N'): ('RER',),
#  ('cadmium sludge from zinc electrolysis stockpiling',
#   'cadmium sludge from zinc electrolysis stockpiling'): ('US',),
#  ('fatty alcohol production, petrochemical', 'fatty alcohol'): ('RER',),
#  ('paper mill construction, non-integrated',
#   'paper mill, non-integrated'): ('RER',),
#  ('market for cement, blast furnace slag 5-25%, US only',
#   'cement, blast furnace slag 5-25%, US only'): ('US',),
#  ('epichlorohydrin production from allyl chloride',
#   'epichlorohydrin'): ('RER',),
#  ('treatment of residue from shredder fraction from manual dismantling, municipal waste incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('treatment of used ventilation control and wiring, decentralized unit',
#   'used ventilation control and wiring decentralized unit'): ('CH',),
#  ('treatment of limestone residue, inert material landfill',
#   'limestone residue'): ('CH',),
#  ('oil boiler production, 100kW', 'oil boiler, 100kW'): ('CH',),
#  ('iron sulfate production', 'iron sulfate'): ('CA-QC', 'RER'),
#  ('citric acid production', 'maize starch'): ('CN', 'RER', 'RNA'),
#  ('esterification of soybean oil', 'vegetable oil methyl ester'): ('BR', 'US'),
#  ('mine infrastructure construction, open cast, peat',
#   'mine infrastructure, open cast, peat'): ('NORDEL',),
#  ('linerboard production, kraftliner',
#   'heat, district or industrial, other than natural gas'): ('CA-QC', 'RER'),
#  ('pyridine-compound production', 'pyridine-compound'): ('RER',),
#  ('heat and power co-generation, natural gas, 200kW electrical, lean burn',
#   'heat, district or industrial, natural gas'): ('CH',),
#  ('indium tin oxide powder production, nanoscale, for sputtering target',
#   'indium tin oxide powder, nanoscale, for sputtering target'): ('RER',),
#  ('solid bleached board production', 'solid bleached board'): ('CA-QC', 'RER'),
#  ('seal production, natural rubber based',
#   'seal, natural rubber based'): ('DE',),
#  ('market for phosgene, liquid', 'phosgene, liquid'): ('RER',),
#  ('market for water works, capacity 1.1E10l/year',
#   'water works, capacity 1.1E10l/year'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland'),
#  ('hydropower plant construction, reservoir',
#   'hydropower plant, reservoir'): ('CA-QC', 'CH'),
#  ('electricity production, photovoltaic, 3kWp facade installation, multi-Si, laminated, integrated',
#   'electricity, low voltage'): ('CH',),
#  ('photovoltaic panel production, CIS', 'photovoltaic panel, CIS'): ('DE',),
#  ('heat distribution equipment production, hydronic radiant floor heating, 150m2',
#   'heat distribution equipment, hydronic radiant floor heating, 150m2'): ('CH',),
#  ('furnace production, wood chips, hardwood storage area, 50kW',
#   'furnace, wood chips, hardwood storage area, 50kW'): ('CH',),
#  ('petroleum refinery operation', 'light fuel oil'): ('CH',
#   'Europe without Switzerland'),
#  ('isobutyl acetate production', 'isobutyl acetate'): ('RER',),
#  ('wheat seed production, organic, for sowing',
#   'wheat seed, organic, for sowing'): ('CH',),
#  ('zeolite production, slurry, without water, in 50% solution state',
#   'zeolite, slurry, without water, in 50% solution state'): ('RER',),
#  ('citric acid production', 'phosphate fertiliser, as P2O5'): ('CN',
#   'RER',
#   'RNA'),
#  ('molecular sieve separation of naphtha', 'hexane'): ('RER',),
#  ('polyvinylfluoride production', 'polyvinylfluoride'): ('US',),
#  ('treatment, sludge from pulp and paper production, landfarming',
#   'sludge from pulp and paper production'): ('CA-QC',),
#  ('maize grain, feed production', 'maize grain, feed'): ('CA-QC',),
#  ('metaldehyde production', 'metaldehyde'): ('RER',),
#  ('transport, passenger car, large size, petrol, EURO 5',
#   'transport, passenger car, large size, petrol, EURO 5'): ('RER',),
#  ('citric acid production', 'lime'): ('CN', 'RER'),
#  ('aluminium milling, large parts',
#   'aluminium removed by milling, large parts'): ('RER',),
#  ('benzyl alcohol production', 'benzyl alcohol'): ('RER',),
#  ('treatment of used toner module, laser printer, colour, recycling',
#   'toner module, laser printer, colour'): ('RER',),
#  ('aluminium turning, primarily dressing, conventional',
#   'aluminium removed by turning, primarily dressing, conventional'): ('RER',),
#  ('fibre cement corrugated slab production',
#   'fibre cement corrugated slab'): ('CH',),
#  ('heat production, untreated waste wood, at furnace 1000-5000 kW',
#   'heat, district or industrial, other than natural gas'): ('CH',),
#  ('hardwood forestry, birch, sustainable forest management',
#   'sawlog and veneer log, hardwood, measured as solid wood under bark'): ('SE',),
#  ('treatment of waste polystyrene isolation, flame-retardant, collection for final disposal',
#   'waste polystyrene isolation, flame-retardant'): ('CH',),
#  ('sodium hypochlorite production, product in 15% solution state',
#   'sodium hypochlorite, without water, in 15% solution state'): ('CA-QC',
#   'RER'),
#  ('cotton production', 'cotton fibre'): ('CN', 'US'),
#  ('linerboard production, kraftliner',
#   'electricity, medium voltage'): ('CA-QC', 'RER'),
#  ('polyethylene pipe production, corrugated, DN 75',
#   'polyethylene pipe, corrugated, DN 75'): ('RER',),
#  ('kenaf production', 'stalk'): ('IN',),
#  ('chlorine dioxide production', 'chlorine dioxide'): ('RER',),
#  ('magnesium-alloy production, AZ91, diecasting',
#   'magnesium-alloy, AZ91, diecast'): ('RER',),
#  ('esterification of rape oil',
#   'potassium sulfate, as K2O'): ('Europe without Switzerland',),
#  ('polyvinylfluoride, film production', 'polyvinylfluoride, film'): ('US',),
#  ('hydrogen sulfide production', 'hydrogen sulfide'): ('RER',),
#  ('heat and power co-generation, diesel, 200kW electrical, SCR-NOx reduction',
#   'electricity, high voltage'): ('BR', 'CH'),
#  ('harvesting, by complete harvester, beets',
#   'harvesting, by complete harvester, beets'): ('CH',),
#  ('spiral-seam duct production, steel, DN 400',
#   'spiral-seam duct, steel, DN 400'): ('RER',),
#  ('water production, deionised, from tap water, at user',
#   'water, deionised, from tap water, at user'): ('CH',),
#  ('heat production, mixed logs, at furnace 100kW',
#   'heat, central or small-scale, other than natural gas'): ('CH',),
#  ('packing, fibre cement product', 'packing, fibre cement product'): ('CH',),
#  ('benzene chlorination', 'monochlorobenzene'): ('RER',),
#  ('treatment of electronics scrap, metals recovery in copper smelter',
#   'lead'): ('SE',),
#  ('methane production, 96% by volume, from biogas, from low pressure network, at service station',
#   'methane, 96% by volume, from biogas, from low pressure network, at service station'): ('CH',),
#  ('magnesium oxide production', 'magnesium oxide'): ('RER',),
#  ('deep well drilling, for deep geothermal power',
#   'deep well, drilled, for geothermal power'): ('AT',
#   'CH',
#   'DE',
#   'HICC',
#   'ID',
#   'IS',
#   'IT',
#   'JP',
#   'MX',
#   'PT',
#   'RU',
#   'TH',
#   'TR',
#   'WECC'),
#  ('cast iron turning, average, computer numerical controlled',
#   'cast iron removed by turning, average, computer numerical controlled'): ('RER',),
#  ('paper production, woodfree, coated, at non-integrated mill',
#   'paper, woodfree, coated'): ('RER',),
#  ('lean concrete production, with cement CEM II/A', 'lean concrete'): ('CH',),
#  ('chlor-alkali electrolysis, mercury cell',
#   'sodium hydroxide, without water, in 50% solution state'): ('RER',),
#  ('acetaldehyde production', 'acetaldehyde'): ('RER',),
#  ('market for municipal solid waste', 'municipal solid waste'): ('CA-QC',
#   'CH'),
#  ('catch crop growing, sunflower, August-October, organic fertiliser 30 kg N',
#   'sunflower silage'): ('CH',),
#  ('treatment of hard coal ash, sanitary landfill', 'hard coal ash'): ('CH',),
#  ('treatment of wastewater from liquid crystal production, capacity 1.1E10l/year',
#   'wastewater from liquid crystal production'): ('CH',),
#  ('heat and power co-generation unit construction, 50kW electrical, components for electricity only',
#   'heat and power co-generation unit, 50kW electrical, components for electricity only'): ('RER',),
#  ('transport, freight, lorry 7.5-16 metric ton, EURO3',
#   'transport, freight, lorry 7.5-16 metric ton, EURO3'): ('RER',),
#  ('steel milling, average', 'steel removed by milling, average'): ('RER',),
#  ('rye production, organic', 'rye grain, organic'): ('CH',),
#  ('steel turning, primarily roughing, conventional',
#   'steel removed by turning, primarily roughing, conventional'): ('RER',),
#  ('market for aluminium scrap, new', 'aluminium scrap, new'): ('RER',),
#  ('treatment of used railway track', 'used railway track'): ('CH',),
#  ('heat, from municipal waste incineration to generic market for heat district or industrial, other than natural gas',
#   'heat, district or industrial, other than natural gas'): ('AT',
#   'BE',
#   'BG',
#   'CA-AB',
#   'CA-NB',
#   'CA-NS',
#   'CA-ON',
#   'CA-PE',
#   'CH',
#   'CZ',
#   'DE',
#   'DK',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'HU',
#   'IT',
#   'JP',
#   'KR',
#   'LU',
#   'NL',
#   'NO',
#   'PL',
#   'PT',
#   'RU',
#   'SE',
#   'SK',
#   'TR',
#   'TW'),
#  ('impact extrusion of aluminium, 4 strokes',
#   'impact extrusion of aluminium, 4 strokes'): ('RER',),
#  ('ventilation of dwellings, central, 1 x 720 m3/h, polyethylene ducts, with earth tube heat exchanger',
#   'ventilation of dwellings, central, 1 x 720 m3/h'): ('CH',),
#  ('treatment of used triple glazing, U<0.5W/m2K, collection for final disposal',
#   'used triple glazing, U<0.5W/m2K'): ('CH',),
#  ('oxidation of methanol', 'steam, in chemical industry'): ('RER',),
#  ('water works construction, capacity 1.1E10l/year, microstrainer treatment',
#   'water works, capacity 1.1E10l/year'): ('CA-QC',
#   'Europe without Switzerland'),
#  ('electricity production, hydro, run-of-river',
#   'electricity, high voltage'): ('ASCC',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'CA-AB',
#   'CA-BC',
#   'CA-MB',
#   'CA-NB',
#   'CA-NF',
#   'CA-NS',
#   'CA-NT',
#   'CA-ON',
#   'CA-QC',
#   'CA-SK',
#   'CA-YK',
#   'CH',
#   'CL',
#   'CN-AH',
#   'CN-BJ',
#   'CN-CQ',
#   'CN-FJ',
#   'CN-GD',
#   'CN-GS',
#   'CN-GX',
#   'CN-GZ',
#   'CN-HA',
#   'CN-HB',
#   'CN-HE',
#   'CN-HL',
#   'CN-HN',
#   'CN-HU',
#   'CN-JL',
#   'CN-JS',
#   'CN-JX',
#   'CN-LN',
#   'CN-NM',
#   'CN-NX',
#   'CN-QH',
#   'CN-SA',
#   'CN-SC',
#   'CN-SX',
#   'CN-TJ',
#   'CN-XJ',
#   'CN-XZ',
#   'CN-YN',
#   'CN-ZJ',
#   'CZ',
#   'DE',
#   'DK',
#   'EE',
#   'ES',
#   'FI',
#   'FR',
#   'FRCC',
#   'GB',
#   'GR',
#   'HICC',
#   'HR',
#   'HU',
#   'IE',
#   'IN',
#   'IR',
#   'IT',
#   'JP',
#   'KR',
#   'LT',
#   'LU',
#   'LV',
#   'MK',
#   'MRO, US only',
#   'MX',
#   'NL',
#   'NPCC, US only',
#   'PL',
#   'PT',
#   'RFC',
#   'RO',
#   'RS',
#   'RU',
#   'SE',
#   'SERC',
#   'SI',
#   'SK',
#   'SPP',
#   'TR',
#   'TRE',
#   'TW',
#   'UA',
#   'WECC, US only'),
#  ('transport, tram', 'transport, tram'): ('CH',),
#  ('door production, inner, wood', 'door, inner, wood'): ('RER',),
#  ('oriented strand board production',
#   'bark chips, wet, measured as dry mass'): ('RER',),
#  ('aluminium alloy production, Metallic Matrix Composite',
#   'aluminium alloy, metal matrix composite'): ('CA-QC',),
#  ('ethanol production from grass',
#   'ethanol, without water, in 95% solution state, from fermentation'): ('CH',),
#  ('window frame production, poly vinyl chloride, U=1.6 W/m2K',
#   'window frame, poly vinyl chloride, U=1.6 W/m2K'): ('RER',),
#  ('market for hard coal', 'hard coal'): ('AU',
#   'CN',
#   'ID',
#   'PL',
#   'RLA',
#   'RNA',
#   'RU',
#   'WEU',
#   'ZA'),
#  ('anhydrite production, burned', 'anhydrite, burned'): ('CH',),
#  ('cement production, alternative constituents 6-20%',
#   'blast furnace slag'): ('CH',),
#  ('cement production, blast furnace slag 66-80%, non-US',
#   'cement, blast furnace slag, 66-80%, non-US'): ('CH',
#   'Europe without Switzerland'),
#  ('plywood production, for indoor use', 'residual wood, dry'): ('RER',),
#  ('heat and power co-generation, natural gas, 50kW electrical, lean burn',
#   'heat, central or small-scale, natural gas'): ('CH',
#   'Europe without Switzerland'),
#  ('argon production, liquid', 'argon, liquid'): ('RER',),
#  ('phenol production', 'phenol'): ('RER',),
#  ('photovoltaic laminate production, CIS',
#   'photovoltaic laminate, CIS'): ('DE',),
#  ('fluorine production, liquid', 'fluorine, liquid'): ('RER',),
#  ('acrylic binder production, product in 34% solution state',
#   'acrylic binder, without water, in 34% solution state'): ('RER',),
#  ('treatment of residue from mechanical treatment, laptop computer, municipal waste incineration',
#   'heat, for reuse in municipal waste incineration only'): (),
#  ('tillage, ploughing', 'tillage, ploughing'): ('CA-QC', 'CH'),
#  ('wood pellet production', 'wood pellet, measured as dry mass'): ('RER',),
#  ('heat and power co-generation, natural gas, 1MW electrical, lean burn',
#   'electricity, high voltage'): ('CH', 'Europe without Switzerland'),
#  ('photovoltaic facade installation, 3kWp, single-Si, panel, mounted, at building',
#   'photovoltaic facade installation, 3kWp, single-Si, panel, mounted, at building'): ('CH',),
#  ('sulfur dioxide production, liquid', 'sulfur dioxide, liquid'): ('RER',),
#  ('o-chlorotoluene production', 'o-chlorotoluene'): ('RER',),
#  ('zinc oxide production', 'zinc oxide'): ('RER',),
#  ('rock wool production', 'rock wool'): ('CH',),
#  ('o-aminophenol production', 'o-aminophenol'): ('RER',),
#  ('toluene oxidation', 'benzoic acid'): ('RER',),
#  ('treatment of used train, passenger, long distance',
#   'used train, passenger, long-distance'): ('CH',),
#  ('housing system construction, pig, label-certified',
#   'housing system, pig, label-certified, per pig place'): ('CH',),
#  ('sugarcane production', 'sugarcane'): ('BR',),
#  ('wood cladding production, softwood',
#   'wood chips, dry, measured as dry mass'): ('CA-QC',),
#  ('market for cement, blast furnace slag 31-50% and 31-50% other alternative constituents',
#   'cement, blast furnace slag 31-50% and 31-50% other alternative constituents'): ('CH',
#   'Europe without Switzerland'),
#  ('wood preservation, spray tunnel/deluging, water-based preservative, indoor use, dry',
#   'wood preservation, spray tunnel/deluging, water-based, indoor use, dry'): ('RER',),
#  ('treatment of high level radioactive waste for final repository',
#   'high level radioactive waste for final repository'): ('CH',),
#  ('market for concrete, sole plate and foundation',
#   'concrete, sole plate and foundation'): ('CH',),
#  ('market for transport, passenger car', 'transport, passenger car'): ('RER',),
#  ('tower silo production, plastic', 'tower silo, plastic'): ('CH',),
#  ('gold-silver mine operation with refinery', 'gold'): ('CA-QC', 'PE', 'PG'),
#  ('cyclohexanone production', 'cyclohexanone'): ('RER',),
#  ('beet sugar production', 'molasses, from sugar beet'): ('CH',),
#  ('treatment of spent anion exchange resin from potable water production, municipal incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('furnace production, wood chips, with silo, 5000kW',
#   'furnace, wood chips, with silo, 5000kW'): ('CH',),
#  ('treatment of spent catalyst base from ethyleneoxide production, residual material landfill',
#   'spent catalyst base from ethyleneoxide production'): ('CH',),
#  ('maintenance, polymer electrolyte membrane fuel cell 2kW electrical',
#   'maintenance, polymer electrolyte membrane fuel cell, 2kW electrical'): ('CH',),
#  ('market for cement, blast furnace slag 66-80%',
#   'cement, blast furnace slag, 66-80%, non-US'): ('CH',
#   'Europe without Switzerland'),
#  ('fodder loading, by self-loading trailer',
#   'fodder loading, by self-loading trailer'): ('CA-QC', 'CH'),
#  ('aluminium drilling, computer numerical controlled',
#   'aluminium removed by drilling, computer numerical controlled'): ('RER',),
#  ('esters of versatic acid production', 'esters of versatic acid'): ('RER',),
#  ('ventilation control and wiring production, central unit',
#   'ventilation control and wiring, central unit'): ('RER',),
#  ('coking', 'coal tar'): ('DE',),
#  ('petrol blending for two-stroke engines', 'petrol, two-stroke blend'): ('CH',
#   'Europe without Switzerland'),
#  ('treatment of wastewater, unpolluted, from residence, capacity 1.1E10l/year',
#   'wastewater, unpolluted, from residence'): ('CH',),
#  ('liquid manure tank trailer production',
#   'liquid manure tank trailer'): ('CH',),
#  ('heat production, softwood chips from forest, at furnace 5000kW',
#   'heat, district or industrial, other than natural gas'): ('CH',),
#  ('willow production, short rotation coppice',
#   'wood chips and particles, willow'): ('DE',),
#  ('glass fibre production', 'glass fibre'): ('RER',),
#  ('sawnwood production, softwood, dried (u=20%), planed',
#   'sawnwood, softwood, dried (u=20%), planed'): ('RER',),
#  ('alpha-naphthol production', 'alpha-naphthol'): ('RER',),
#  ('market for electricity, low voltage', 'electricity, low voltage'): ('ASCC',
#   'AT',
#   'AU',
#   'BA',
#   'BE',
#   'BG',
#   'BR',
#   'CA-AB',
#   'CA-BC',
#   'CA-MB',
#   'CA-NB',
#   'CA-NF',
#   'CA-NS',
#   'CA-NT',
#   'CA-NU',
#   'CA-ON',
#   'CA-PE',
#   'CA-QC',
#   'CA-SK',
#   'CA-YK',
#   'CH',
#   'CL',
#   'CSG',
#   'CY',
#   'CZ',
#   'DE',
#   'DK',
#   'EE',
#   'ES',
#   'FI',
#   'FR',
#   'FRCC',
#   'GB',
#   'GR',
#   'HICC',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IN',
#   'IR',
#   'IS',
#   'IT',
#   'JP',
#   'KR',
#   'LT',
#   'LU',
#   'LV',
#   'MK',
#   'MRO, US only',
#   'MT',
#   'MX',
#   'MY',
#   'NL',
#   'NO',
#   'NPCC, US only',
#   'PE',
#   'PL',
#   'PT',
#   'RFC',
#   'RO',
#   'RS',
#   'RU',
#   'SA',
#   'SE',
#   'SERC',
#   'SGCC',
#   'SI',
#   'SK',
#   'SPP',
#   'TH',
#   'TR',
#   'TRE',
#   'TW',
#   'TZ',
#   'UA',
#   'WECC, US only',
#   'ZA'),
#  ('transport, passenger car, large size, petrol, EURO 3',
#   'transport, passenger car, large size, petrol, EURO 3'): ('RER',),
#  ('unkown land use, on arable land recently transformed from primary forest',
#   'unknown land use'): ('BR', 'CO', 'MY'),
#  ('cement production, pozzolana and fly ash 5-15%, US only',
#   'hard coal ash'): ('US',),
#  ('carbon tetrachloride production', 'carbon tetrachloride'): ('RER',),
#  ('ammonium sulfate production', 'ammonium sulfate, as N'): ('RER',),
#  ('isopropanol production', 'isopropanol'): ('RER',),
#  ('calcium nitrate production', 'ammonium nitrate, as N'): ('RER',),
#  ('treatment of aluminium scrap, post-consumer, prepared for recycling, at refiner',
#   'aluminium, cast alloy'): ('RER',),
#  ('fatty acid production, from vegetable oil', 'fatty acid'): ('RER',),
#  ('clinker production', 'waste paint'): ('CH',
#   'Europe without Switzerland',
# ...
#  ('fibreboard production, soft, latex bonded',
#   'fibreboard, soft, latex bonded'): ('CH',),
#  ('pentaerythritol production in sodium hydroxide solution',
#   'pentaerythritol'): ('RER',),
#  ('treatment of waste vapour barrier, flame-retarded, municipal incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('milk spray-drying', 'spray-drying of milk'): ('CA-QC',),
#  ('rape oil mill operation', 'rape meal'): ('CH',
#   'Europe without Switzerland'),
#  ('impact extrusion of steel, warm, 3 strokes',
#   'impact extrusion of steel, warm, 3 strokes'): ('RER',),
#  ('treatment of used blower and heat exchange unit, KWLC 1200',
#   'used blower and heat exchange unit KWLC 1200'): ('CH',),
#  ('cane sugar production with ethanol by-product',
#   'electricity, high voltage'): ('BR',),
#  ('beam, hardwood, raw, air drying to u=20%',
#   'sawnwood, beam, hardwood, raw, dried (u=20%)'): ('CA-QC', 'CH'),
#  ('cyclic N-compound production', 'cyclic N-compound'): ('RER',),
#  ('citric acid production',
#   'grass silage, Swiss integrated production'): ('CN', 'RER', 'RNA'),
#  ('esterquat production, from coconut oil and palm kernel oil',
#   'esterquat'): ('RER',),
#  ('catch crop growing, ryegrass, August-April, organic fertiliser 60 kg N, three cuts',
#   'ryegrass silage'): ('CH',),
#  ('transport, freight, lorry 7.5-16 metric ton, EURO5',
#   'transport, freight, lorry 7.5-16 metric ton, EURO5'): ('RER',),
#  ('engineered wood joist production', 'joist, engineered wood'): ('CA-QC',),
#  ('transport, freight, aircraft, intracontinental',
#   'transport, freight, aircraft'): ('RER',),
#  ('treatment of used double glazing, U<1.1W/m2K, laminated safety glass, collection for final disposal',
#   'used double glazing, U<1.1W/m2K, laminated safety glass'): ('CH',),
#  ('primary zinc production from concentrate',
#   'cadmium sludge from zinc electrolysis'): ('CA-QC',),
#  ('electricity production, photovoltaic, 3kWp slanted-roof installation, a-Si, laminated, integrated',
#   'electricity, low voltage'): ('CH',),
#  ('treatment of waste polyethylene, municipal incineration',
#   'heat, for reuse in municipal waste incineration only'): (),
#  ('aluminium casting facility construction',
#   'aluminium casting facility'): ('RER',),
#  ('packing, cement', 'packing, cement'): ('CH',),
#  ('heat production, lignite briquette, at stove 5-15kW',
#   'heat, central or small-scale, other than natural gas'): ('Europe without Switzerland',),
#  ('molecular sieve separation of naphtha', '2-methylpentane'): ('RER',),
#  ('bitumen seal production, VA4', 'bitumen seal, VA4'): ('RER',),
#  ('nuclear fuel element production, for pressure water reactor, UO2 3.8% & MOX',
#   'nuclear fuel element, for pressure water reactor, UO2 3.8% & MOX'): ('FR',),
#  ('chlor-alkali electrolysis, diaphragm cell', 'chlorine, gaseous'): ('RER',),
#  ('wood preservation, dipping/immersion, water-based preservative, indoor use, dry',
#   'wood preservation, dipping/immersion method, water-based, indoor use, dry'): ('RER',),
#  ('treatment of waste emulsion paint, municipal incineration',
#   'waste emulsion paint'): ('CH',),
#  ('treatment of wastewater from ground granulated blast furnace slag production',
#   'wastewater from ground granulated blast furnace slag production'): ('US',),
#  ('potassium chloride production', 'potassium chloride, as K2O'): ('CA-SK',
#   'RER'),
#  ('gold-silver-zinc-lead-copper mine operation and refining', 'lead'): ('SE',),
#  ('operation, computer, laptop, 23% active work',
#   'operation, computer, laptop, 23% active work'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland'),
#  ('ammonium nitrite production', 'ammonium nitrite'): ('RER',),
#  ('transport, freight, lorry >32 metric ton, EURO3',
#   'transport, freight, lorry >32 metric ton, EURO3'): ('RER',),
#  ('expanded perlite production', 'expanded perlite'): ('CH',),
#  ('fatty alcohol sulfate production, palm oil',
#   'fatty alcohol sulfate'): ('RER',),
#  ('sweet gas, burned in gas turbine',
#   'sweet gas, burned in gas turbine'): ('NO',),
#  ('mine construction, underground, hard coal',
#   'mine infrastructure, underground, hard coal'): ('CN',),
#  ('market for wood pellet', 'wood pellet, measured as dry mass'): ('RER',),
#  ('steel production, electric, chromium steel 18/8',
#   'steel, chromium steel 18/8'): ('RER',),
#  ('petroleum refinery operation', 'liquefied petroleum gas'): ('CH',
#   'Europe without Switzerland'),
#  ('fava bean seed production, organic, for sowing',
#   'fava bean seed, organic, for sowing'): ('CH',),
#  ('treatment of wastewater from cathode ray tube production, capacity 1.1E10l/year',
#   'wastewater from cathode ray tube production'): ('CH',),
#  ('photovoltaic slanted-roof installation, 3kWp, ribbon-Si, laminated, integrated, on roof',
#   'photovoltaic slanted-roof installation, 3kWp, ribbon-Si, laminated, integrated, on roof'): ('CH',),
#  ('concrete block production', 'concrete block'): ('DE',),
#  ('treatment of decommissioned road', 'decommissioned road'): ('RER',),
#  ('waste collection lorry production, 21 metric ton',
#   'waste collection lorry, 21 metric ton'): ('CH',),
#  ('furnace production, wood chips, average storage area, 50kW',
#   'furnace, wood chips, average storage area, 50kW'): ('CH',),
#  ('blower and heat exchange unit production, Twl-700',
#   'blower and heat exchange unit, Twl-700'): ('RER',),
#  ('treatment of municipal solid waste, incineration',
#   'municipal solid waste'): ('AT',
#   'BE',
#   'BG',
#   'CA-AB',
#   'CA-NB',
#   'CA-NS',
#   'CA-ON',
#   'CA-PE',
#   'CA-QC',
#   'CH',
#   'CZ',
#   'DE',
#   'DK',
#   'ES',
#   'FI',
#   'FR',
#   'GB',
#   'HU',
#   'IT',
#   'JP',
#   'KR',
#   'LU',
#   'NL',
#   'NO',
#   'PL',
#   'PT',
#   'RU',
#   'SE',
#   'SK',
#   'TR',
#   'TW'),
#  ('carton board box production service, with offset printing',
#   'carton board box production, with offset printing'): ('CA-QC', 'CH'),
#  ('concrete production, for building construction, with cement CEM II/A',
#   'concrete, high exacting requirements'): ('CH',),
#  ('pyrethroid-compound production', 'pyrethroid-compound'): ('RER',),
#  ('allyl chloride production, reaction of propylene and chlorine',
#   'allyl chloride'): ('RER',),
#  ('uranium production, in yellowcake', 'uranium, in yellowcake'): ('RNA',),
#  ('treatment of waste polypropylene, sanitary landfill',
#   'waste polypropylene'): ('CH',),
#  ('phenoxy-compound production', 'phenoxy-compound'): ('RER',),
#  ('polystyrene foam slab production, 45% recycled',
#   'polystyrene foam slab'): ('CH',),
#  ('zinc coating, coils', 'zinc coat, coils'): ('RER',),
#  ('particle board production, for indoor use, from virgin wood',
#   'particle board, for indoor use'): ('BR',),
#  ('treatment of wastewater from ceramic production, capacity 5E9l/year',
#   'wastewater from ceramic production'): ('CH',),
#  ('steel production, low-alloyed, hot rolled',
#   'steel, low-alloyed, hot rolled'): ('RER',),
#  ('acetic acid production, product in 98% solution state',
#   'acetic acid, without water, in 98% solution state'): ('RER',),
#  ('sewer grid construction, 1E9l/year, 30 km',
#   'sewer grid, 1E9l/year, 30 km'): ('CH',),
#  ('treatment of automobile catalyst', 'palladium'): ('RER',),
#  ('alpha-picoline production', 'alpha-picoline'): ('RER',),
#  ('nylon 6 production, glass-filled', 'nylon 6, glass-filled'): ('RER',),
#  ('market for cement, pozzolana and fly ash 11-35%',
#   'cement, pozzolana and fly ash 11-35%, non-US'): ('CH',
#   'Europe without Switzerland'),
#  ('rare earth oxides production from bastnäsite concentrate',
#   'cerium concentrate, 60% cerium oxide'): ('CN',),
#  ('lorry production, 16 metric ton', 'lorry, 16 metric ton'): ('RER',),
#  ('transport, passenger car, medium size, diesel, EURO 5',
#   'transport, passenger car, medium size, diesel, EURO 5'): ('RER',),
#  ('aircraft production, long haul', 'aircraft, long haul'): ('RER',),
#  ('graphic paper production, 100% recycled',
#   'graphic paper, 100% recycled'): ('RER',),
#  ('treatment of dust, unalloyed electric arc furnace steel, residual material landfill',
#   'dust, unalloyed electric arc furnace steel'): ('CH',),
#  ('miscanthus rhizome production, for planting',
#   'miscanthus, chopped'): ('DE',),
#  ('foam glass production, electricity, label-certified',
#   'foam glass, electricity, label-certified'): ('RER',),
#  ('heat production, at coal coke industrial furnace 1-10MW',
#   'heat, district or industrial, other than natural gas'): ('CA-QC',),
#  ('compressed air production, 800 kPa gauge, >30kW, optimized generation',
#   'compressed air, 800 kPa gauge'): ('RER',),
#  ('sulfur trioxide production', 'sulfur trioxide'): ('RER',),
#  ('sodium metasilicate pentahydrate production, 58% active substance, powder',
#   'sodium metasilicate pentahydrate, 58% active substance, powder'): ('RER',),
#  ('cast iron turning, primarily roughing, computer numerical controlled',
#   'cast iron removed by turning, primarily roughing, computer numerical controlled'): ('RER',),
#  ('treatment of waste plastic, mixture, sanitary landfill',
#   'waste plastic, mixture'): ('CH',),
#  ('treatment of scrap lead acid battery, remelting', 'lead'): ('RER',),
#  ('operation, computer, desktop, with cathode ray tube display, active mode',
#   'operation, computer, desktop, with cathode ray tube display, active mode'): ('CA-QC',
#   'CH',
#   'Europe without Switzerland'),
#  ('steel milling, small parts',
#   'steel removed by milling, small parts'): ('RER',),
#  ('sawing, hardwood', 'sawnwood, hardwood, raw'): ('CA-QC', 'CH'),
#  ('cadmium telluride production, semiconductor-grade',
#   'cadmium telluride, semiconductor-grade'): ('US',),
#  ('shed construction', 'shed'): ('CH',),
#  ('maleic anhydride production by catalytic oxidation of benzene',
#   'steam, in chemical industry'): ('RER',),
#  ('p-nitrotoluene production', 'p-nitrotoluene'): ('RER',),
#  ('weaving, bast fibre', 'weaving, bast fibre'): ('IN',),
#  ('recultivation, bentonite mine', 'recultivation, bentonite mine'): ('DE',),
#  ('sawnwood production, softwood, raw, dried (u=20%)',
#   'sawnwood, softwood, raw, dried (u=20%)'): ('RER',),
#  ('industrial machine production, heavy, unspecified',
#   'industrial machine, heavy, unspecified'): ('RER',),
#  ('N,N-dimethylformamide production', 'N,N-dimethylformamide'): ('RER',),
#  ('furnace production, wood chips, softwood storage area, 50kW',
#   'furnace, wood chips, softwood storage area, 50kW'): ('CH',),
#  ('market for wood chips, wet, measured as dry mass',
#   'wood chips, wet, measured as dry mass'): ('CH',
#   'Europe without Switzerland'),
#  ('transport, freight, lorry 3.5-7.5 metric ton, EURO6',
#   'transport, freight, lorry 3.5-7.5 metric ton, EURO6'): ('RER',),
#  ('phenolic resin production', 'phenolic resin'): ('RER',),
#  ('treatment of tyre wear emissions, lorry',
#   'tyre wear emissions, lorry'): ('RER',),
#  ('hardwood forestry, oak, sustainable forest management',
#   'sawlog and veneer log, hardwood, measured as solid wood under bark'): ('DE',),
#  ('soybean meal and crude oil production', 'soybean oil, crude'): ('BR',
#   'RER',
#   'US'),
#  ('planing, beam, hardwood, u=10%',
#   'sawnwood, beam, hardwood, dried (u=10%), planed'): ('CA-QC', 'CH'),
#  ('treatment of waste glass, municipal incineration', 'waste glass'): ('CH',),
#  ('lightweight concrete block production, expanded clay',
#   'lightweight concrete block, expanded clay'): ('CH',),
#  ('ethanol production from whey',
#   'ethanol, without water, in 95% solution state, from fermentation'): ('CH',),
#  ('ethanol production from whey', 'fodder yeast'): ('CH',),
#  ('cobwork production', 'cobwork'): ('CH',),
#  ('beam, softwood, raw, air drying to u=20%',
#   'sawnwood, beam, softwood, raw, dried (u=20%)'): ('CA-QC', 'CH'),
#  ('stirling heat and power co-generation unit construction, 3kW electrical, future',
#   'stirling heat and power co-generation unit, 3kW electrical, future'): ('CH',),
#  ('enamelling', 'enamelling'): ('CA-QC', 'RER'),
#  ('treatment of scrap printed wiring boards, shredding and separation',
#   'used printed wiring boards'): ('CA-QC',),
#  ('wheat production, organic', 'wheat grain, organic'): ('CH',),
#  ('treatment of bilge oil, hazardous waste incineration',
#   'bilge oil'): ('CH',),
#  ('ventilation duct production, steel, 100x50 mm',
#   'ventilation duct, steel, 100x50 mm'): ('RER',),
#  ('treatment of salt tailing from potash mine, residual material landfill',
#   'salt tailing from potash mine'): ('CH',),
#  ('softwood forestry, spruce, sustainable forest management',
#   'pulpwood, softwood, measured as solid wood under bark'): ('DE', 'SE'),
#  ('ethylene glycol diethyl ether production',
#   'ethylene glycol diethyl ether'): ('RER',),
#  ('energy saving, from ventilation system, 6 x 120 m3/h, steel ducts, with earth tube heat exchanger',
#   'energy saving'): ('CH',),
#  ('fatty alcohol sulfate production, from palm kernel oil',
#   'fatty alcohol sulfate'): ('RER',),
#  ('lithium fluoride production', 'lithium fluoride'): ('CN',),
#  ('energy saving, from ventilation system, 1 x 720 m3/h, steel ducts, with earth tube heat exchanger',
#   'energy saving'): ('CH',),
#  ('furnace production, logs, hardwood storage area, 100kW',
#   'furnace, logs, hardwood storage area, 100kW'): ('CH',),
#  ('maintenance, lorry 16 metric ton',
#   'maintenance, lorry 16 metric ton'): ('CH',),
#  ('dimethyl sulfate production', 'dimethyl sulfate'): ('RER',),
#  ('electricity production, natural gas, combined cycle power plant',
#   'electricity, high voltage'): ('ASCC',
#   'AT',
#   'AU',
#   'BE',
#   'BR',
#   'CA-AB',
#   'CA-BC',
#   'CA-MB',
#   'CA-NB',
#   'CA-NS',
#   'CA-NT',
#   'CA-ON',
#   'CA-SK',
#   'CL',
#   'CN-AH',
#   'CN-BJ',
#   'CN-CQ',
#   'CN-FJ',
#   'CN-GD',
#   'CN-GS',
#   'CN-GX',
#   'CN-GZ',
#   'CN-HA',
#   'CN-HB',
#   'CN-HE',
#   'CN-HL',
#   'CN-HN',
#   'CN-HU',
#   'CN-JL',
#   'CN-JS',
#   'CN-JX',
#   'CN-LN',
#   'CN-NM',
#   'CN-NX',
#   'CN-QH',
#   'CN-SA',
#   'CN-SC',
#   'CN-SD',
#   'CN-SH',
#   'CN-SX',
#   'CN-TJ',
#   'CN-XJ',
#   'CN-XZ',
#   'CN-YN',
#   'CN-ZJ',
#   'CZ',
#   'DE',
#   'ES',
#   'FI',
#   'FR',
#   'FRCC',
#   'GB',
#   'GR',
#   'HR',
#   'HU',
#   'ID',
#   'IE',
#   'IN',
#   'IR',
#   'IT',
#   'JP',
#   'KR',
#   'MRO, US only',
#   'MX',
#   'MY',
#   'NL',
#   'NO',
#   'NPCC, US only',
#   'PE',
#   'PT',
#   'RFC',
#   'RU',
#   'SA',
#   'SERC',
#   'SK',
#   'SPP',
#   'TH',
#   'TR',
#   'TRE',
#   'TW',
#   'UA',
#   'WECC, US only'),
#  ('planing, board, hardwood, u=10%',
#   'sawnwood, board, hardwood, dried (u=10%), planed'): ('CA-QC', 'CH'),
#  ('lath, softwood, raw, kiln drying to u=10%',
#   'sawnwood, lath, softwood, raw, dried (u=10%)'): ('CA-QC', 'CH'),
#  ('operation, computer, laptop, videoconference, label-certified electricity',
#   'operation, computer, laptop, videoconference, label-certified electricity'): ('CH',),
#  ('impact extrusion of steel, warm, initial warming',
#   'impact extrusion of steel, warm, initial warming'): ('RER',),
#  ('treatment of waste expanded polystyrene, municipal incineration',
#   'electricity, for reuse in municipal waste incineration only'): (),
#  ('treatment of pollutant from rail ballast, residual material landfill',
#   'pollutant from rail ballast'): ('CH',),
#  ('trichloroethylene production', 'trichloroethylene'): ('WEU',),
#  ('treatment, sludge from pulp and paper production, landfarming',
#   'soil pH raising agent, as CaCO3'): ('CA-QC',),
#  ('transport, passenger car, EURO 5',
#   'transport, passenger car, EURO 5'): ('RER',),
#  ('sour gas, burned in gas turbine',
#   'sour gas, burned in gas turbine'): ('NO',),
#  ('rye production', 'rye grain'): ('RER',),
#  ('metal coating facility construction', 'metal coating facility'): ('RER',),
#  ('market for light fuel oil', 'light fuel oil'): ('CH',
#   'Europe without Switzerland'),
#  ('treatment of waste plastic, mixture, municipal incineration',
#   'waste plastic, mixture'): ('CH',),
#  ('aluminium around steel bi-metal stranded cable production, 3x3.67mm external diameter wire',
#   'aluminium around steel bi-metal stranded cable, 3x3.67mm external diameter wire'): ('CA-QC',),
#  ('cement production, pozzolana and fly ash 5-15%, US only',
#   'cement, pozzolana and fly ash 5-15%, US only'): ('US',),
#  ('anodising, aluminium sheet', 'anodising, aluminium sheet'): ('CA-QC',
#   'RER'),
#  ('melamine production', 'melamine'): ('RER',),
#  ('soybean meal and crude oil production, mechanical extraction',
#   'soybean meal'): ('CA-QC',),
#  ...}

# %%
name, product = ('field application of compost', 'phosphate fertiliser, as P2O5')
[x for x in Database("ecoinvent 3.2 cutoff") if x['name'] == name and x['reference product'] == product]
# Out:
# ['field application of compost' (kilogram, GLO, None)]

# %% [markdown]
# # Check to see if other databases have new RoWs

# %%
all_rows = {x[0] for x in row_locations}
rows_in_databases = {'ecoinvent 3.2 cutoff': all_rows}

# %%
for name, fp in ecoinvents[-1::-1]:
    if name == 'ecoinvent 3.2 cutoff':
        continue
    else:
        _, data, _, _ = discretize_rest_of_world(name, warn=False)
        new_rows = {x[0] for x in data}
        print(name, len(new_rows.difference(all_rows)))
        rows_in_databases[name] = new_rows
        all_rows = all_rows.union(new_rows)
# Out:
# ecoinvent 3.2 apos 4
# ecoinvent 3.2 consequential 0
# ecoinvent 3.1 apos 38
# ecoinvent 3.1 cutoff 0
# ecoinvent 3.1 consequential 0
# ecoinvent 3.01 consequential 19
# ecoinvent 3.01 apos 1
# ecoinvent 3.01 cutoff 0

# %%
len(all_rows)
# Out:
# Warning: DisplayFormatter._ipython_display_formatter_default is deprecated: use @default decorator instead.
# Warning: DisplayFormatter._formatters_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._singleton_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._type_printers_default is deprecated: use @default decorator instead.
# Warning: PlainTextFormatter._deferred_printers_default is deprecated: use @default decorator instead.
# 202

# %%
all_rows_sorted = sorted(all_rows, key=lambda x: str(x))

# %%
all_rows_sorted = [("RoW-{}".format(i + 1), x) for i, x in enumerate(all_rows_sorted)]

# %%
all_rows_sorted
# Out:
# [(('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-1'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CSG',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IS',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SGCC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-2'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IS',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-3'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'Québec',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-4'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-5'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'IE',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-6'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-7'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-8'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-9'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'Québec',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-10'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN-AH',
#    'CN-FJ',
#    'CN-GD',
#    'CN-HB',
#    'CN-HE',
#    'CN-HN',
#    'CN-HU',
#    'CN-JS',
#    'CN-LN',
#    'CN-SD',
#    'CN-SX',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'IE',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MRO, US only',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-11'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-12'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-13'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SA',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only'),
#   'RoW-14'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only'),
#   'RoW-15'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-16'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-17'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'Québec',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-18'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'Québec',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-19'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CL',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MRO, US only',
#    'MX',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-20'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HR',
#    'IE',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'SERC',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-21'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'IE',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-22'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BR',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MK',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RU',
#    'SA',
#    'SERC',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'WECC, US only'),
#   'RoW-23'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CL',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PT',
#    'RFC',
#    'RU',
#    'SA',
#    'SERC',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only'),
#   'RoW-24'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CN',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'MT',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'WECC, US only'),
#   'RoW-25'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'WECC, US only'),
#   'RoW-26'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-BC',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CH',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'Québec',
#    'RFC',
#    'RO',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'WECC, US only'),
#   'RoW-27'),
#  (('ASCC',
#    'AT',
#    'AU',
#    'BE',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CZ',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'IE',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MRO, US only',
#    'NO',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RS',
#    'SE',
#    'SERC',
#    'SK',
#    'SPP',
#    'TRE',
#    'WECC, US only',
#    'ZA'),
#   'RoW-28'),
#  (('ASCC',
#    'AT',
#    'BA',
#    'CA-AB',
#    'CA-BC',
#    'CA-NT',
#    'CA-YK',
#    'CH',
#    'FR',
#    'HR',
#    'IN',
#    'IT',
#    'JP',
#    'MK',
#    'MRO, US only',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'RFC',
#    'RS',
#    'SERC',
#    'WECC, US only'),
#   'RoW-29'),
#  (('ASCC',
#    'AU',
#    'BA',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-NS',
#    'CA-ON',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'ES',
#    'FRCC',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'ID',
#    'IN',
#    'IT',
#    'KR',
#    'MK',
#    'MRO, US only',
#    'MX',
#    'NPCC, US only',
#    'RFC',
#    'RO',
#    'RS',
#    'SERC',
#    'SI',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'WECC, US only'),
#   'RoW-30'),
#  (('AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CN',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HR',
#    'HU',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW',
#    'UA'),
#   'RoW-31'),
#  (('AT',
#    'AU',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HR',
#    'HU',
#    'IE',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'NO',
#    'PL',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW',
#    'UA'),
#   'RoW-32'),
#  (('AT',
#    'AU',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN-AH',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-HA',
#    'CN-HU',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HU',
#    'ID',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'TH',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-33'),
#  (('AT',
#    'AU',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN-AH',
#    'CN-GD',
#    'CN-GS',
#    'CN-HA',
#    'CN-HU',
#    'CN-JS',
#    'CN-JX',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HU',
#    'ID',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LT',
#    'LU',
#    'MT',
#    'MX',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'SA',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'TH',
#    'TRE',
#    'TW',
#    'TZ',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-34'),
#  (('AT',
#    'AU',
#    'BE',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'WECC, US only'),
#   'RoW-35'),
#  (('AT',
#    'AU',
#    'BE',
#    'BR',
#    'CN-AH',
#    'CN-BJ',
#    'CN-CQ',
#    'CN-FJ',
#    'CN-GD',
#    'CN-GS',
#    'CN-GX',
#    'CN-GZ',
#    'CN-HA',
#    'CN-HB',
#    'CN-HE',
#    'CN-HL',
#    'CN-HN',
#    'CN-HU',
#    'CN-JL',
#    'CN-JS',
#    'CN-JX',
#    'CN-LN',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SC',
#    'CN-SD',
#    'CN-SH',
#    'CN-SX',
#    'CN-TJ',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'NO',
#    'PL',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW',
#    'UA'),
#   'RoW-36'),
#  (('AT',
#    'AU',
#    'BE',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HU',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MX',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PT',
#    'RFC',
#    'SE',
#    'SERC',
#    'SI',
#    'TH',
#    'TW',
#    'WECC, US only',
#    'ZA'),
#   'RoW-37'),
#  (('AT',
#    'AU',
#    'BE',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'CH',
#    'CN',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HU',
#    'IN',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MX',
#    'MY',
#    'NL',
#    'NPCC, US only',
#    'PT',
#    'Québec',
#    'RFC',
#    'SE',
#    'SERC',
#    'SI',
#    'TH',
#    'TW',
#    'WECC, US only',
#    'ZA'),
#   'RoW-38'),
#  (('AT',
#    'AU',
#    'BE',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'IE',
#    'IT',
#    'KR',
#    'LU',
#    'MX',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'SE',
#    'SI',
#    'SK',
#    'TH',
#    'TR'),
#   'RoW-39'),
#  (('AT',
#    'AU',
#    'BE',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'IE',
#    'IT',
#    'KR',
#    'LU',
#    'MX',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'Québec',
#    'SE',
#    'SI',
#    'SK',
#    'TH',
#    'TR'),
#   'RoW-40'),
#  (('AT',
#    'AU',
#    'BE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'GR',
#    'HICC',
#    'HR',
#    'HU',
#    'IE',
#    'IN',
#    'IR',
#    'IT',
#    'KR',
#    'LT',
#    'LU',
#    'LV',
#    'MRO, US only',
#    'MX',
#    'MY',
#    'NL',
#    'NO',
#    'NPCC, US only',
#    'PE',
#    'PL',
#    'PT',
#    'RFC',
#    'RO',
#    'RS',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TH',
#    'TR',
#    'TRE',
#    'TW',
#    'WECC, US only'),
#   'RoW-41'),
#  (('AT',
#    'AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'CN-GD',
#    'CN-GS',
#    'CN-HA',
#    'CN-JS',
#    'CN-NM',
#    'CN-NX',
#    'CN-QH',
#    'CN-SA',
#    'CN-SD',
#    'CN-XJ',
#    'CN-XZ',
#    'CN-YN',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'GB',
#    'HICC',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'NPCC, US only',
#    'PT',
#    'RFC',
#    'SERC',
#    'WECC, US only'),
#   'RoW-42'),
#  (('AT',
#    'AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CA-SK',
#    'CA-YK',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'HICC',
#    'IT',
#    'JP',
#    'KR',
#    'NL',
#    'NPCC, US only',
#    'PT',
#    'RFC',
#    'SERC',
#    'WECC, US only'),
#   'RoW-43'),
#  (('AT',
#    'AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-NU',
#    'CA-ON',
#    'CA-PE',
#    'CA-SK',
#    'CA-YK',
#    'DE',
#    'ES',
#    'FR',
#    'FRCC',
#    'HICC',
#    'IT',
#    'JP',
#    'KR',
#    'NL',
#    'NPCC, US only',
#    'PT',
#    'Québec',
#    'RFC',
#    'SERC',
#    'WECC, US only'),
#   'RoW-44'),
#  (('AT',
#    'BA',
#    'BE',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CN',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HR',
#    'HU',
#    'IN',
#    'IR',
#    'IT',
#    'JP',
#    'KR',
#    'MX',
#    'NL',
#    'PL',
#    'RO',
#    'RS',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW',
#    'UA'),
#   'RoW-45'),
#  (('AT',
#    'BA',
#    'BE',
#    'CN',
#    'DE',
#    'ES',
#    'FR',
#    'HR',
#    'IT',
#    'JP',
#    'KR',
#    'RS',
#    'RU'),
#   'RoW-46'),
#  (('AT', 'BA', 'CZ', 'DE', 'ES', 'FR', 'GR', 'HU', 'MK', 'PL', 'SI', 'SK'),
#   'RoW-47'),
#  (('AT',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-48'),
#  (('AT',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'ID',
#    'IE',
#    'IN',
#    'IS',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'MY',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RS',
#    'RU',
#    'SE',
#    'SI',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-49'),
#  (('AT',
#    'BE',
#    'BG',
#    'CA-AB',
#    'CA-NB',
#    'CA-NS',
#    'CA-ON',
#    'CA-PE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-50'),
#  (('AT',
#    'BE',
#    'BG',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-51'),
#  (('AT',
#    'BE',
#    'BG',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'HU',
#    'IT',
#    'JP',
#    'KR',
#    'LU',
#    'NL',
#    'NO',
#    'PL',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'TR',
#    'TW'),
#   'RoW-52'),
#  (('AT',
#    'BE',
#    'CA-AB',
#    'CA-QC',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'NL',
#    'SE',
#    'SK',
#    'US'),
#   'RoW-53'),
#  (('AT',
#    'BE',
#    'CH',
#    'CZ',
#    'DE',
#    'DK',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'HU',
#    'IE',
#    'IT',
#    'JP',
#    'NL',
#    'RNA',
#    'SE',
#    'SK'),
#   'RoW-54'),
#  (('AT', 'BE', 'CZ', 'DE', 'ES', 'FR', 'HR', 'IT', 'NL', 'PL', 'PT', 'SK'),
#   'RoW-55'),
#  (('AT', 'BE', 'DE', 'FR', 'IT'), 'RoW-56'),
#  (('AT',
#    'CH',
#    'DE',
#    'HICC',
#    'ID',
#    'IS',
#    'IT',
#    'JP',
#    'MX',
#    'PT',
#    'RU',
#    'TH',
#    'TR',
#    'WECC'),
#   'RoW-57'),
#  (('AT',
#    'CH',
#    'DE',
#    'HICC',
#    'ID',
#    'IS',
#    'IT',
#    'JP',
#    'MX',
#    'PT',
#    'RU',
#    'TH',
#    'TR',
#    'WECC, US only'),
#   'RoW-58'),
#  (('AT', 'CZ', 'DE', 'DK', 'FI', 'KR', 'NL', 'NO', 'PL', 'RU', 'SE', 'SK'),
#   'RoW-59'),
#  (('AT',
#    'DE',
#    'HICC',
#    'ID',
#    'IT',
#    'JP',
#    'MX',
#    'PT',
#    'RU',
#    'TH',
#    'TR',
#    'WECC, US only'),
#   'RoW-60'),
#  (('AU',
#    'BA',
#    'BG',
#    'BR',
#    'CA-AB',
#    'CA-MB',
#    'CA-ON',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'GR',
#    'HR',
#    'HU',
#    'ID',
#    'IN',
#    'MK',
#    'PL',
#    'RO',
#    'RS',
#    'RU',
#    'SI',
#    'SK',
#    'TH',
#    'TR',
#    'TW',
#    'UA'),
#   'RoW-61'),
#  (('AU', 'CA', 'TZ', 'US', 'ZA'), 'RoW-62'),
#  (('AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'KR',
#    'RU',
#    'TR',
#    'UA'),
#   'RoW-63'),
#  (('AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'CL',
#    'ID',
#    'IN',
#    'IR',
#    'KR',
#    'MX',
#    'MY',
#    'PE',
#    'SA',
#    'TH',
#    'TR',
#    'TW'),
#   'RoW-64'),
#  (('AU',
#    'CA-AB',
#    'CA-BC',
#    'CA-MB',
#    'CA-NB',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-SK',
#    'KR',
#    'Québec',
#    'RU',
#    'TR',
#    'UA'),
#   'RoW-65'),
#  (('AU', 'CH', 'IN', 'KR', 'MX', 'MY', 'TW', 'ZA'), 'RoW-66'),
#  (('AU', 'CN', 'ID', 'PL', 'RLA', 'RNA', 'RU', 'WEU', 'ZA'), 'RoW-67'),
#  (('AU', 'KR', 'RU', 'TR'), 'RoW-68'),
#  (('AU', 'RAS', 'RER', 'RLA', 'RNA'), 'RoW-69'),
#  (('AU',), 'RoW-70'),
#  (('BA',
#    'BE',
#    'CN',
#    'DE',
#    'ES',
#    'FR',
#    'HR',
#    'IT',
#    'JP',
#    'KR',
#    'NL',
#    'RS',
#    'RU'),
#   'RoW-71'),
#  (('BE',
#    'BG',
#    'BR',
#    'CA-NB',
#    'CA-ON',
#    'CH',
#    'CN',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HU',
#    'IN',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'Québec',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-72'),
#  (('BE',
#    'BG',
#    'BR',
#    'CH',
#    'CN',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HU',
#    'IN',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-73'),
#  (('BE',
#    'BG',
#    'BR',
#    'CH',
#    'CN-GD',
#    'CN-JS',
#    'CN-ZJ',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FR',
#    'FRCC',
#    'GB',
#    'HU',
#    'IR',
#    'JP',
#    'KR',
#    'MRO, US only',
#    'NL',
#    'NPCC, US only',
#    'RFC',
#    'RO',
#    'RU',
#    'SE',
#    'SERC',
#    'SI',
#    'SK',
#    'SPP',
#    'TRE',
#    'TW',
#    'UA',
#    'WECC, US only',
#    'ZA'),
#   'RoW-74'),
#  (('BE', 'CN', 'DE', 'DK', 'FI', 'GB', 'IE', 'JP', 'NL', 'NO', 'SE'),
#   'RoW-75'),
#  (('BE',), 'RoW-76'),
#  (('BG',
#    'CH',
#    'CL',
#    'EE',
#    'HR',
#    'ID',
#    'IN',
#    'LT',
#    'LV',
#    'MX',
#    'MY',
#    'PE',
#    'RU',
#    'TH',
#    'TR',
#    'TW',
#    'TZ',
#    'UA',
#    'ZA'),
#   'RoW-77'),
#  (('BR', 'CA-QC', 'CH', 'CN', 'DE', 'ES', 'FR', 'IN', 'MY', 'PH', 'TN', 'US'),
#   'RoW-78'),
#  (('BR', 'CA-QC', 'CH', 'CN', 'DE', 'ES', 'FR', 'IN', 'MY', 'PH', 'US'),
#   'RoW-79'),
#  (('BR', 'CA-QC', 'US'), 'RoW-80'),
#  (('BR', 'CH'), 'RoW-81'),
#  (('BR', 'CH', 'CN', 'DE', 'ES', 'FR', 'IN', 'MY', 'PH', 'US'), 'RoW-82'),
#  (('BR', 'CH', 'CN', 'Europe without Switzerland', 'US'), 'RoW-83'),
#  (('BR', 'CH', 'Europe without Switzerland', 'US'), 'RoW-84'),
#  (('BR', 'CO'), 'RoW-85'),
#  (('BR', 'CO', 'IN', 'MY'), 'RoW-86'),
#  (('BR', 'CO', 'MY'), 'RoW-87'),
#  (('BR', 'CO', 'RAF'), 'RoW-88'),
#  (('BR', 'ID', 'MY', 'TH'), 'RoW-89'),
#  (('BR', 'RER', 'US'), 'RoW-90'),
#  (('BR', 'US'), 'RoW-91'),
#  (('BR',), 'RoW-92'),
#  (('CA',), 'RoW-93'),
#  (('CA-AB', 'CA-QC', 'DE', 'DZ', 'NL', 'NO', 'RU'), 'RoW-94'),
#  (('CA-AB', 'DE', 'DZ', 'RU', 'US'), 'RoW-95'),
#  (('CA-AB', 'NG', 'NL', 'US'), 'RoW-96'),
#  (('CA-AB',), 'RoW-97'),
#  (('CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-NT',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FRCC',
#    'HICC',
#    'IS',
#    'KR',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TZ',
#    'ZA'),
#   'RoW-98'),
#  (('CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-ON',
#    'CA-QC',
#    'CA-SK',
#    'CN',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FRCC',
#    'HICC',
#    'KR',
#    'PT',
#    'RU',
#    'SE',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TZ',
#    'ZA'),
#   'RoW-99'),
#  (('CA-MB',
#    'CA-NB',
#    'CA-NF',
#    'CA-NS',
#    'CA-ON',
#    'CA-SK',
#    'CN',
#    'CZ',
#    'DE',
#    'ES',
#    'FI',
#    'FRCC',
#    'HICC',
#    'KR',
#    'PT',
#    'Québec',
#    'RU',
#    'SE',
#    'SK',
#    'SPP',
#    'TR',
#    'TRE',
#    'TZ',
#    'ZA'),
#   'RoW-100'),
#  (('CA-NB', 'CA-ON', 'CA-QC'), 'RoW-101'),
#  (('CA-QC', 'CH'), 'RoW-102'),
#  (('CA-QC', 'CH', 'Europe without Switzerland'), 'RoW-103'),
#  (('CA-QC', 'CH', 'Europe without Switzerland', 'US'), 'RoW-104'),
#  (('CA-QC', 'CH', 'FR'), 'RoW-105'),
#  (('CA-QC', 'CN'), 'RoW-106'),
#  (('CA-QC',
#    'CN',
#    'IAI Area 1, Africa',
#    'IAI Area 2, without Quebec',
#    'IAI Area 3, South America',
#    'IAI Area 4&5, without China',
#    'IAI Area 8, Gulf',
#    'IAI Area, EU27 & EFTA',
#    'IAI Area, Europe outside EU & EFTA',
#    'UN-OCEANIA'),
#   'RoW-107'),
#  (('CA-QC',
#    'CN',
#    'IAI Area 1, Africa',
#    'IAI Area 2, without Quebec',
#    'IAI Area 3, South America',
#    'IAI Area 4&5, without China',
#    'IAI Area 8, Gulf',
#    'UN-EUROPE',
#    'UN-OCEANIA'),
#   'RoW-108'),
#  (('CA-QC', 'DE'), 'RoW-109'),
#  (('CA-QC', 'DE', 'ES', 'FR'), 'RoW-110'),
#  (('CA-QC', 'DE', 'ES', 'FR', 'US'), 'RoW-111'),
#  (('CA-QC', 'DE', 'FR', 'US'), 'RoW-112'),
#  (('CA-QC', 'Europe without Switzerland'), 'RoW-113'),
#  (('CA-QC', 'FR'), 'RoW-114'),
#  (('CA-QC',
#    'IAI Area 2, without Quebec',
#    'IAI Area 3, South America',
#    'IAI Area 4&5, without China',
#    'IAI Area, EU27 & EFTA',
#    'IAI Area, Europe outside EU & EFTA'),
#   'RoW-115'),
#  (('CA-QC',
#    'IAI Area 2, without Quebec',
#    'IAI Area 3, South America',
#    'IAI Area 4&5, without China',
#    'UN-EUROPE'),
#   'RoW-116'),
#  (('CA-QC', 'PE', 'PG'), 'RoW-117'),
#  (('CA-QC', 'RER'), 'RoW-118'),
#  (('CA-QC', 'US'), 'RoW-119'),
#  (('CA-QC',), 'RoW-120'),
#  (('CA-SK', 'RER'), 'RoW-121'),
#  (('CH', 'CL', 'IN', 'MX', 'PE', 'RU', 'TH', 'TR', 'TW', 'ZA'), 'RoW-122'),
#  (('CH', 'CN'), 'RoW-123'),
#  (('CH', 'CN', 'DE', 'FR', 'US'), 'RoW-124'),
#  (('CH', 'CN', 'Europe without Switzerland'), 'RoW-125'),
#  (('CH', 'CN', 'Europe without Switzerland', 'US'), 'RoW-126'),
#  (('CH', 'CN', 'FR', 'US'), 'RoW-127'),
#  (('CH',
#    'DE',
#    'ES',
#    'FI',
#    'FRCC',
#    'IN',
#    'JP',
#    'MRO, US only',
#    'MX',
#    'NPCC, US only',
#    'RFC',
#    'RU',
#    'SE',
#    'SERC',
#    'SPP',
#    'TRE',
#    'TW',
#    'WECC, US only'),
#   'RoW-128'),
#  (('CH', 'DE', 'NL'), 'RoW-129'),
#  (('CH', 'DE', 'RER w/o CH+DE'), 'RoW-130'),
#  (('CH', 'DE', 'US'), 'RoW-131'),
#  (('CH', 'Europe without Switzerland'), 'RoW-132'),
#  (('CH', 'Europe without Switzerland', 'US'), 'RoW-133'),
#  (('CH', 'FR'), 'RoW-134'),
#  (('CH', 'SE'), 'RoW-135'),
#  (('CH',), 'RoW-136'),
#  (('CL', 'IN', 'MX', 'PE', 'RU', 'TH', 'TR', 'TW', 'ZA'), 'RoW-137'),
#  (('CL',), 'RoW-138'),
#  (('CM',), 'RoW-139'),
#  (('CN', 'DE', 'GB', 'NL', 'RU'), 'RoW-140'),
#  (('CN', 'Europe without Switzerland', 'US'), 'RoW-141'),
#  (('CN',
#    'IAI Area 1, Africa',
#    'IAI Area 2, without Quebec',
#    'IAI Area 4&5, without China',
#    'IAI Area, EU27 & EFTA',
#    'IAI Area, Europe outside EU & EFTA',
#    'UN-OCEANIA'),
#   'RoW-142'),
#  (('CN', 'RER'), 'RoW-143'),
#  (('CN', 'RER', 'RNA'), 'RoW-144'),
#  (('CN', 'RU'), 'RoW-145'),
#  (('CN', 'US'), 'RoW-146'),
#  (('CN',), 'RoW-147'),
#  (('CO', 'IN', 'RAF'), 'RoW-148'),
#  (('CO', 'MY'), 'RoW-149'),
#  (('CO',), 'RoW-150'),
#  (('CZ', 'DE', 'GR', 'PL', 'RU', 'SI', 'SK'), 'RoW-151'),
#  (('DE', 'DZ', 'NL', 'NO', 'RU'), 'RoW-152'),
#  (('DE', 'DZ', 'RNA', 'RU'), 'RoW-153'),
#  (('DE', 'ES', 'FR'), 'RoW-154'),
#  (('DE', 'ES', 'FR', 'US'), 'RoW-155'),
#  (('DE', 'FR', 'IT'), 'RoW-156'),
#  (('DE', 'FR', 'US'), 'RoW-157'),
#  (('DE', 'GB', 'NL', 'RU'), 'RoW-158'),
#  (('DE', 'NL', 'RER w/o DE+NL+NO', 'RU'), 'RoW-159'),
#  (('DE', 'SE'), 'RoW-160'),
#  (('DE', 'UCTE without Germany'), 'RoW-161'),
#  (('DE', 'US'), 'RoW-162'),
#  (('DE',), 'RoW-163'),
#  (('DK',), 'RoW-164'),
#  (('DZ',), 'RoW-165'),
#  (('EE', 'FI', 'IE', 'RU', 'SE'), 'RoW-166'),
#  (('ES',), 'RoW-167'),
#  (('Europe without NORDEL (NCPA)', 'NORDEL'), 'RoW-168'),
#  (('Europe without Switzerland',), 'RoW-169'),
#  (('FI', 'IE', 'RU', 'SE'), 'RoW-170'),
#  (('FR', 'US'), 'RoW-171'),
#  (('FR',), 'RoW-172'),
#  (('GB', 'NL', 'NO'), 'RoW-173'),
#  (('GB', 'NO'), 'RoW-174'),
#  (('GB',), 'RoW-175'),
#  (('IAI Area, EU27 & EFTA',), 'RoW-176'),
#  (('IL',), 'RoW-177'),
#  (('IN',), 'RoW-178'),
#  (('JP', 'RER'), 'RoW-179'),
#  (('MA', 'US'), 'RoW-180'),
#  (('MA',), 'RoW-181'),
#  (('MY',), 'RoW-182'),
#  (('NG', 'NL'), 'RoW-183'),
#  (('NG',), 'RoW-184'),
#  (('NL',), 'RoW-185'),
#  (('NO',), 'RoW-186'),
#  (('NORDEL',), 'RoW-187'),
#  (('PE', 'PG'), 'RoW-188'),
#  (('PH',), 'RoW-189'),
#  (('PT',), 'RoW-190'),
#  (('RAF', 'RME', 'RU'), 'RoW-191'),
#  (('RER',), 'RoW-192'),
#  (('RNA',), 'RoW-193'),
#  (('SE',), 'RoW-194'),
#  (('SK',), 'RoW-195'),
#  (('TH',), 'RoW-196'),
#  (('TR',), 'RoW-197'),
#  (('UCTE',), 'RoW-198'),
#  (('US',), 'RoW-199'),
#  (('WEU',), 'RoW-200'),
#  (('ZA',), 'RoW-201'),
#  ((), 'RoW-202')]

# %%
import json

with open("rows-ecoinvent.json", "w") as f:
    json.dump(all_rows_sorted, f, indent=2)
